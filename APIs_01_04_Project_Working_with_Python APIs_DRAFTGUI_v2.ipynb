# %%
## BRAZILIAN CITIES - MANUAL TEST

from bokeh.plotting import output_file, show
from bokeh.models import Select, Div, Button, CustomJS
from bokeh.models.widgets import DateRangePicker, Paragraph
from bokeh.layouts import column, row
from bokeh.io import curdoc
from IPython.display import display, HTML

# Output to a new HTML file
output_file("index.html")

# City to airport mapping
city_airports = {
    "Rio de Janeiro": ["Galeão", "Santos Dumont"],
    "Sao Paulo": ["Guarulhos", "Congonhas"],
    "Bahia": ["Deputado Luís Eduardo Magalhães"],
    "Pernambuco": ["Guararapes"]
}

# Create Select for city input with some example cities
city_select = Select(title="City:", value="Rio de Janeiro", options=list(city_airports.keys()))

# Create a Button to update the recommended dates
update_button = Button(label="Discover this city", css_classes=['custom-button'])

# Create a DateRangePicker widget
date_range_picker = DateRangePicker(title="Select a date range:")

# Create a Paragraph to show recommended dates
recommended_dates_text = Paragraph(text="According to the weather crystal ball, your recommended dates are: ")

# Create a Div element for displaying the selected city and date range
result_div = Div()

# Display the logo image using IPython.display.Image
logo_image = Div(text="<img src='sunnylogo.png' style='width:100px;height:100px;'>")

# Create a Div for the title with custom CSS style for the font and background color
title_div = Div(text="<h1 style='font-family: Cooper Black, sans-serif; font-size: 36px;'><center>Holidays by Sunny Side Up</center></h1>",
                sizing_mode='stretch_width', css_classes=['title-div'])

# Create a row layout for the header and the logo
header = row(logo_image, title_div)

# Create an empty airport select, to be populated based on city selection
airport_select = Select(title="Airport:", value="Galeão", options=city_airports[city_select.value])

# Function to update the options of airport select based on city selection
def update_airport_options():
    city = city_select.value
    airport_select.options = city_airports[city]

# CustomJS callback to update airport options when city changes
city_select.js_on_change('value', CustomJS(args=dict(airport_select=airport_select), code="""
    const city_airports = %s;
    const city = cb_obj.value;
    airport_select.options = city_airports[city];
    airport_select.value = city_airports[city][0];
""" % city_airports))

# Function to handle city selection change
def update_selected_city(attr, old, new):
    update_airport_options()
    result_div.text = f"Selected city: {new}"

# Function to handle button click to update the recommended dates
def update_recommended_dates():
    recommended_dates_text.text = f"According to the weather crystal ball, your recommended dates for {city_select.value} are:"

# Function to handle date range picker change
def show_selected_date_range(attr, old, new):
    start_date, end_date = date_range_picker.value_as_datetime
    result_div.text = f"Selected city: {city_select.value}<br>Selected date range: {start_date} to {end_date}"

# Attach the functions to the button click events
update_button.on_click(update_recommended_dates)
date_range_picker.on_change('value', show_selected_date_range)

# Attach the function to the city select change event
originLocationCode=city_select.on_change('value', update_selected_city)

# Layout the widgets initially with city input, button, and result div
inputs = column(city_select, airport_select, update_button, recommended_dates_text, date_range_picker, result_div)

# Set the background color for the whole layout
layout = column(header, inputs, sizing_mode='stretch_both', css_classes=['app-layout'])

# Display the plot
show(layout)
# Out:
# WARNING:bokeh.embed.util:
# You are generating standalone HTML/JS output, but trying to use real Python
# callbacks (i.e. with on_change or on_event). This combination cannot work.
#
# Only JavaScript callbacks may be used with standalone output. For more
# information on JavaScript callbacks with Bokeh, see:
#
#     https://docs.bokeh.org/en/latest/docs/user_guide/interaction/callbacks.html
#
# Alternatively, to use real Python callbacks, a Bokeh server application may
# be used. For more information on building and running Bokeh applications, see:
#
#     https://docs.bokeh.org/en/latest/docs/user_guide/server.html

# %%
##GREEK CITIES MANUAL TEST WITH THE AIRPORT
from bokeh.plotting import output_file, show
from bokeh.models import Select, Div, Button, CustomJS
from bokeh.models.widgets import DateRangePicker, Paragraph
from bokeh.layouts import column, row
from IPython.display import display, HTML

# Output to a new HTML file
output_file("index.html")

# City to airport mapping for Greek cities
city_airports = {
    "Athens": ["Athens International Airport"],
    "Corfu": ["Ioannis Kapodistrias International Airport"],
    "Crete": ["Heraklion International Airport", "Chania International Airport"],
    "Zakynthos": ["Zakynthos International Airport"],
    "Mykonos": ["Mykonos International Airport"]
}

# Create Select for city input with Greek cities
city_select = Select(title="City:", value="Athens", options=list(city_airports.keys()))

# Create a Button to update the recommended dates
update_button = Button(label="Discover this city", css_classes=['custom-button'])

# Create a DateRangePicker widget
date_range_picker = DateRangePicker(title="Select a date range:")

# Create a Paragraph to show recommended dates
recommended_dates_text = Paragraph(text="According to the weather crystal ball, your recommended dates are: ")

# Create a Div element for displaying the selected city and date range
result_div = Div()

# Display the logo image using IPython.display.Image
logo_image = Div(text="<img src='sunnylogo.png' style='width:100px;height:100px;'>")

# Create a Div for the title with custom CSS style for the font and background color
title_div = Div(text="<h1 style='font-family: Cooper Black, sans-serif; font-size: 36px;'><center>Holidays by Sunny Side Up</center></h1>",
                sizing_mode='stretch_width', css_classes=['title-div'])

# Create a row layout for the header and the logo
header = row(logo_image, title_div)

# Create an empty airport select, to be populated based on city selection
airport_select = Select(title="Airport:", value="Athens International Airport", options=city_airports[city_select.value])

# Function to update the options of airport select based on city selection
def update_airport_options():
    city = city_select.value
    airport_select.options = city_airports[city]

# CustomJS callback to update airport options when city changes
city_select.js_on_change('value', CustomJS(args=dict(airport_select=airport_select), code="""
    const city_airports = %s;
    const city = cb_obj.value;
    airport_select.options = city_airports[city];
    airport_select.value = city_airports[city][0];
""" % city_airports))

# Function to handle city selection change
def update_selected_city(attr, old, new):
    update_airport_options()
    result_div.text = f"Selected city: {new}"

# Function to handle button click to update the recommended dates
def update_recommended_dates():
    recommended_dates_text.text = f"According to the weather crystal ball, your recommended dates for {city_select.value} are:"

# Function to handle date range picker change
def show_selected_date_range(attr, old, new):
    start_date, end_date = date_range_picker.value_as_datetime
    result_div.text = f"Selected city: {city_select.value}<br>Selected date range: {start_date} to {end_date}"

# Attach the functions to the button click events
update_button.on_click(update_recommended_dates)
date_range_picker.on_change('value', show_selected_date_range)

# Attach the function to the city select change event
city_select.on_change('value', update_selected_city)

# Layout the widgets initially with city input, button, and result div
inputs = column(city_select, airport_select, update_button, recommended_dates_text, date_range_picker, result_div)

# Set the background color for the whole layout
layout = column(header, inputs, sizing_mode='stretch_both', css_classes=['app-layout'])

# Display the plot
show(layout)
# Out:
# WARNING:bokeh.embed.util:
# You are generating standalone HTML/JS output, but trying to use real Python
# callbacks (i.e. with on_change or on_event). This combination cannot work.
#
# Only JavaScript callbacks may be used with standalone output. For more
# information on JavaScript callbacks with Bokeh, see:
#
#     https://docs.bokeh.org/en/latest/docs/user_guide/interaction/callbacks.html
#
# Alternatively, to use real Python callbacks, a Bokeh server application may
# be used. For more information on building and running Bokeh applications, see:
#
#     https://docs.bokeh.org/en/latest/docs/user_guide/server.html

# %%
#GREEK CITIES CSV TEST (WITHOUT THE AIRPORT)
from bokeh.plotting import output_file, show
from bokeh.models import Select, Div, Button, CustomJS, ColumnDataSource
from bokeh.models.widgets import DateRangePicker, Paragraph
from bokeh.layouts import column, row
from bokeh.io import curdoc
import pandas as pd

# Read the CSV file
df = pd.read_csv('all_forecast.csv')

# Get unique city names from the CSV
cities = df['city'].unique().tolist()

# Output to a new HTML file
output_file("index.html")

# Create Select for city input with the cities from the CSV
city_select = Select(title="City:", value=cities[0], options=cities)

# Create a Button to update the recommended dates
update_button = Button(label="Discover this city", css_classes=['custom-button'])

# Create a DateRangePicker widget
date_range_picker = DateRangePicker(title="Select a date range:")

# Create a Paragraph to show recommended dates
recommended_dates_text = Paragraph(text="According to the weather crystal ball, your recommended dates are: ")

# Create a Div element for displaying the selected city and date range
result_div = Div()

# Display the logo image using IPython.display.Image
logo_image = Div(text="<img src='sunnylogo.png' style='width:100px;height:100px;'>")

# Create a Div for the title with custom CSS style for the font and background color
title_div = Div(text="<h1 style='font-family: Cooper Black, sans-serif; font-size: 36px; color: teal;'><center>Holidays by Sunny Side Up</center></h1>",
                sizing_mode='stretch_width', css_classes=['title-div'])

# Create a row layout for the header and the logo
header = row(logo_image, title_div)

# Function to handle city selection change
def update_selected_city(attr, old, new):
    result_div.text = f"Selected city: {new}"

# Function to handle button click to update the recommended dates
def update_recommended_dates():
    selected_city = city_select.value
    start_date, end_date = date_range_picker.value_as_datetime
    filtered_df = df[(df['city'] == selected_city) & (df['date'] >= start_date) & (df['date'] <= end_date)]
    
    if not filtered_df.empty:
        # Assuming you want to display some statistics or details about the selected city and date range
        avg_temp = filtered_df['temp'].mean()
        avg_humidity = filtered_df['humidity'].mean()
        recommended_dates_text.text = f"Avg. temperature: {avg_temp:.2f}°C<br>Avg. humidity: {avg_humidity:.2f}%"
    else:
        recommended_dates_text.text = f"No data available for {selected_city} in the selected date range."

# Function to handle date range picker change
def show_selected_date_range(attr, old, new):
    result_div.text = f"Selected city: {city_select.value}<br>Selected date range: {new[0]} to {new[1]}"

# Attach the functions to the button click events
update_button.on_click(update_recommended_dates)
date_range_picker.on_change('value', show_selected_date_range)

# Attach the function to the city select change event
city_select.on_change('value', update_selected_city)

# Layout the widgets initially with city input, button, and result div
inputs = column(city_select, recommended_dates_text, date_range_picker, update_button, result_div)

# Set the background color for the whole layout
layout = column(header, inputs, sizing_mode='stretch_both', css_classes=['app-layout'])

# Display the plot
show(layout)
# Out:
# WARNING:bokeh.embed.util:
# You are generating standalone HTML/JS output, but trying to use real Python
# callbacks (i.e. with on_change or on_event). This combination cannot work.
#
# Only JavaScript callbacks may be used with standalone output. For more
# information on JavaScript callbacks with Bokeh, see:
#
#     https://docs.bokeh.org/en/latest/docs/user_guide/interaction/callbacks.html
#
# Alternatively, to use real Python callbacks, a Bokeh server application may
# be used. For more information on building and running Bokeh applications, see:
#
#     https://docs.bokeh.org/en/latest/docs/user_guide/server.html

# %%
##ATTEMPTING TO GRAB FROM URL

import requests
import pandas as pd
from datetime import datetime

weather_key = "11da115d9a8d4556bd993522240506"
api_key = weather_key

# Function to fetch weather data for the next 10 days for a single city
def fetch_10_day_forecast(city, api_key):
    base_url = 'http://api.weatherapi.com/v1'
    url = f"{base_url}/forecast.json?key={api_key}&q={city}&days=10"
    response = requests.get(url)
    data = response.json()
    
    # Check if the response contains the necessary forecast data
    if 'forecast' in data and 'forecastday' in data['forecast']:
        forecast_data = data['forecast']['forecastday']
        extracted_data = []
        
        for day in forecast_data:
            date = day['date']
            temp = day['day']['avgtemp_c']
            humidity = day['day']['avghumidity']
            cloudiness = day['day']['condition']['text']
            wind_speed = day['day']['maxwind_kph']
            
            extracted_data.append({
                'city': city,
                'date': date,
                'temp': temp,
                'humidity': humidity,
                'condition': cloudiness,
                'wind_speed': wind_speed
            })
        
        return pd.DataFrame(extracted_data)
    else:
        print(f"No forecast data available for {city}")
        return pd.DataFrame()

# List of cities
cities = ['Athens', 'Corfu', 'Crete', 'Zante', 'Mykonos']

# API key
api_key = weather_key  # Replace with your actual API key

# Initialize an empty DataFrame to store the combined forecast data
all_forecast_df = pd.DataFrame()

# Loop through each city and fetch the forecast data
for city in cities:
    city_forecast_df = fetch_10_day_forecast(city, api_key)
    all_forecast_df = pd.concat([all_forecast_df, city_forecast_df], ignore_index=True)

# Display the combined DataFrame
display(all_forecast_df)

#all_forecast_df.to_csv('all_forecast')
# Out:
#        city        date  temp  humidity           condition  wind_speed
# 0    Athens  2024-06-05  28.7        33  Patchy rain nearby        19.1
# 1    Athens  2024-06-06  27.5        40               Sunny        15.1
# 2    Athens  2024-06-07  26.1        49  Patchy rain nearby        25.6
# 3    Athens  2024-06-08  26.0        40               Sunny        28.1
# 4    Athens  2024-06-09  26.3        34               Sunny        24.1
# 5    Athens  2024-06-10  26.7        34               Sunny        13.7
# 6    Athens  2024-06-11  29.1        38               Sunny        19.8
# 7    Athens  2024-06-12  30.6        30               Sunny        14.0
# 8    Athens  2024-06-13  29.4        38               Sunny        13.3
# 9    Athens  2024-06-14  28.5        46               Sunny        14.8
# 10    Corfu  2024-06-05  21.5        80  Patchy rain nearby        16.6
# 11    Corfu  2024-06-06  19.4        79  Patchy rain nearby        29.5
# 12    Corfu  2024-06-07  12.5        88       Moderate rain        20.9
# 13    Corfu  2024-06-08  13.6        86       Moderate rain        32.0
# 14    Corfu  2024-06-09  13.2        90       Moderate rain        22.3
# 15    Corfu  2024-06-10  12.4        87  Patchy rain nearby        19.4
# 16    Corfu  2024-06-11  15.5        76      Partly Cloudy         18.0
# 17    Corfu  2024-06-12  18.0        82  Patchy rain nearby        27.7
# 18    Corfu  2024-06-13  16.8        80      Partly Cloudy         16.6
# 19    Corfu  2024-06-14  17.9        74  Patchy rain nearby        26.3
# 20    Crete  2024-06-05  29.6        23               Sunny         8.6
# 21    Crete  2024-06-06  28.8        24               Sunny        11.2
# 22    Crete  2024-06-07  23.6        46  Patchy rain nearby        19.8
# 23    Crete  2024-06-08  22.9        47               Sunny        26.3
# 24    Crete  2024-06-09  22.8        40               Sunny        24.8
# 25    Crete  2024-06-10  25.0        34               Sunny        18.7
# 26    Crete  2024-06-11  29.4        30               Sunny        16.2
# 27    Crete  2024-06-12  30.9        22               Sunny        20.5
# 28    Crete  2024-06-13  29.3        25               Sunny        13.7
# 29    Crete  2024-06-14  29.5        22               Sunny        15.8
# 30    Zante  2024-06-05  16.0        64               Sunny        14.4
# 31    Zante  2024-06-06  13.9        64      Partly Cloudy         20.9
# 32    Zante  2024-06-07  12.0        68  Patchy rain nearby        16.9
# 33    Zante  2024-06-08  13.0        68      Partly Cloudy         16.9
# 34    Zante  2024-06-09  14.1        67  Patchy rain nearby        21.6
# 35    Zante  2024-06-10  11.0        72               Sunny        23.0
# 36    Zante  2024-06-11  13.8        61               Sunny        14.0
# 37    Zante  2024-06-12  13.9        55      Partly Cloudy         14.0
# 38    Zante  2024-06-13  14.5        64               Sunny        17.6
# 39    Zante  2024-06-14  15.4        71  Patchy rain nearby        20.9
# 40  Mykonos  2024-06-05  25.6        66               Sunny        16.9
# 41  Mykonos  2024-06-06  23.9        74  Patchy rain nearby        39.2
# 42  Mykonos  2024-06-07  23.0        78               Sunny        55.8
# 43  Mykonos  2024-06-08  22.8        76               Sunny        52.6
# 44  Mykonos  2024-06-09  23.1        73               Sunny        50.0
# 45  Mykonos  2024-06-10  24.7        67               Sunny        34.6
# 46  Mykonos  2024-06-11  26.2        67               Sunny        14.4
# 47  Mykonos  2024-06-12  25.7        71               Sunny        23.8
# 48  Mykonos  2024-06-13  24.6        76               Sunny        23.0
# 49  Mykonos  2024-06-14  24.2        75               Sunny        26.6

# %%
##attempting to get from URL
import requests
import pandas as pd
from datetime import datetime
from bokeh.plotting import output_file, show
from bokeh.models import Select, Div, Button, CustomJS, ColumnDataSource
from bokeh.models.widgets import DateRangePicker, Paragraph
from bokeh.layouts import column, row
from bokeh.io import curdoc

# WeatherAPI key
weather_key = "11da115d9a8d4556bd993522240506"

# Function to fetch weather data from WeatherAPI
def fetch_weather_data(city, weather_key):
    base_url = 'http://api.weatherapi.com/v1'
    url = f"{base_url}/forecast.json?key={weather_key}&q={city}&days=10"
    response = requests.get(url)
    data = response.json()
    return data

# Read the CSV file
df = pd.read_csv('all_forecast.csv')

# Get unique city names from the CSV
cities = df['city'].unique().tolist()

# Output to a new HTML file
output_file("index.html")

# Create Select for city input with the cities from the CSV
city_select = Select(title="City:", value=cities[0], options=cities)

# Create a Button to update the recommended dates
update_button = Button(label="Discover this city", css_classes=['custom-button'])

# Create a DateRangePicker widget
date_range_picker = DateRangePicker(title="Select a date range:")

# Create a Paragraph to show recommended dates
recommended_dates_text = Paragraph(text="According to the weather crystal ball, your recommended dates are: ")

# Create a Div element for displaying the selected city and date range
result_div = Div()

# Display the logo image using IPython.display.Image
logo_image = Div(text="<img src='sunnylogo.png' style='width:100px;height:100px;'>")

# Create a Div for the title with custom CSS style for the font and background color
title_div = Div(text="<h1 style='font-family: Cooper Black, sans-serif; font-size: 36px; color: teal;'><center>Holidays by Sunny Side Up</center></h1>",
                sizing_mode='stretch_width', css_classes=['title-div'])

# Create a row layout for the header and the logo
header = row(logo_image, title_div)

# Function to handle city selection change
def update_selected_city(attr, old, new):
    result_div.text = f"Selected city: {new}"

# Function to handle button click to update the recommended dates
def update_recommended_dates():
    selected_city = city_select.value
    start_date, end_date = date_range_picker.value_as_datetime
    
    # Fetch weather data for the selected city
    data = fetch_weather_data(selected_city, weather_key)
    
    # Process the data as per your requirement
    if 'error' not in data:
        # Assuming you want to display some statistics or details about the selected city and date range
        # Extract relevant data from the API response
        forecast = data['forecast']['forecastday']
        
        # Example: Calculate average temperature and humidity from the forecast
        avg_temp = sum([day['day']['avgtemp_c'] for day in forecast]) / len(forecast)
        avg_humidity = sum([day['day']['avghumidity'] for day in forecast]) / len(forecast)
        
        # Update the recommended dates text
        recommended_dates_text.text = f"Avg. temperature: {avg_temp:.2f}°C<br>Avg. humidity: {avg_humidity:.2f}%"
        
    else:
        recommended_dates_text.text = f"No data available for {selected_city} in the selected date range."

# Function to handle date range picker change
def show_selected_date_range(attr, old, new):
    result_div.text = f"Selected city: {city_select.value}<br>Selected date range: {new[0]} to {new[1]}"

# Attach the functions to the button click events
update_button.on_click(update_recommended_dates)
date_range_picker.on_change('value', show_selected_date_range)

# Attach the function to the city select change event
city_select.on_change('value', update_selected_city)

# Layout the widgets initially with city input, button, and result div
inputs = column(city_select, date_range_picker, update_button)
results = column(recommended_dates_text, result_div)
layout = column(header, inputs, results, sizing_mode='stretch_both', css_classes=['app-layout'])

# Display the plot
show(layout)
# Out:
# WARNING:bokeh.embed.util:
# You are generating standalone HTML/JS output, but trying to use real Python
# callbacks (i.e. with on_change or on_event). This combination cannot work.
#
# Only JavaScript callbacks may be used with standalone output. For more
# information on JavaScript callbacks with Bokeh, see:
#
#     https://docs.bokeh.org/en/latest/docs/user_guide/interaction/callbacks.html
#
# Alternatively, to use real Python callbacks, a Bokeh server application may
# be used. For more information on building and running Bokeh applications, see:
#
#     https://docs.bokeh.org/en/latest/docs/user_guide/server.html

# %%
import requests
import pandas as pd
from datetime import datetime, timedelta

# WeatherAPI key
weather_key = "11da115d9a8d4556bd993522240506"

# Function to fetch weather data for the next 10 days for a single city
def fetch_10_day_forecast(city, api_key):
    base_url = 'http://api.weatherapi.com/v1'
    url = f"{base_url}/forecast.json?key={api_key}&q={city}&days=10"
    response = requests.get(url)
    data = response.json()
    
    # Check if the response contains the necessary forecast data
    if 'forecast' in data and 'forecastday' in data['forecast']:
        forecast_data = data['forecast']['forecastday']
        extracted_data = []
        
        for day in forecast_data:
            date = day['date']
            temp = day['day']['avgtemp_c']
            humidity = day['day']['avghumidity']
            cloudiness = day['day']['condition']['text']
            wind_speed = day['day']['maxwind_kph']
            
            extracted_data.append({
                'city': city,
                'date': date,
                'temp': temp,
                'humidity': humidity,
                'condition': cloudiness,
                'wind_speed': wind_speed
            })
        
        return pd.DataFrame(extracted_data)
    else:
        print(f"No forecast data available for {city}")
        return pd.DataFrame()

# Function to find the best 7 consecutive days based on specific filters
def find_best_7_days(forecast_df, criteria='temp'):
    best_city = None
    best_start_date = None
    best_average = float('-inf') if criteria == 'temp' else float('inf')
    
    for city in forecast_df['city'].unique():
        city_df = forecast_df[forecast_df['city'] == city]
        
        # Ensure the dates are sorted
        city_df = city_df.sort_values(by='date')
        
        # Iterate over possible 7-day windows
        for i in range(len(city_df) - 6):
            window = city_df.iloc[i:i+7]
            
            if criteria == 'temp':
                average = window['temp'].mean()
                if average > best_average:
                    best_average = average
                    best_city = city
                    best_start_date = window.iloc[0]['date']
            elif criteria == 'humidity':
                average = window['humidity'].mean()
                if average < best_average:
                    best_average = average
                    best_city = city
                    best_start_date = window.iloc[0]['date']
            elif criteria == 'wind_speed':
                average = window['wind_speed'].mean()
                if average < best_average:
                    best_average = average
                    best_city = city
                    best_start_date = window.iloc[0]['date']
    
    return best_city, best_start_date, best_average

# List of cities
cities = ['Athens', 'Corfu', 'Crete', 'Zante', 'Mykonos']

# API key
api_key = weather_key  # Replace with your actual API key

# Initialize an empty DataFrame to store the combined forecast data
all_forecast_df = pd.DataFrame()

# Loop through each city and fetch the forecast data
for city in cities:
    city_forecast_df = fetch_10_day_forecast(city, api_key)
    all_forecast_df = pd.concat([all_forecast_df, city_forecast_df], ignore_index=True)

# Display the combined DataFrame
display(all_forecast_df)

# Find the best 7 consecutive days for each criteria
best_city_temp, best_start_date_temp, best_average_temp = find_best_7_days(all_forecast_df, criteria='temp')
best_city_humidity, best_start_date_humidity, best_average_humidity = find_best_7_days(all_forecast_df, criteria='humidity')
best_city_wind_speed, best_all_forecast_dfstart_date_wind_speed, best_average_wind_speed = find_best_7_days(all_forecast_df, criteria='wind_speed')

print(f"Best week based on high temperature: {best_city_temp}, starting from {best_start_date_temp} with average temp {best_average_temp}")
print(f"Best week based on low humidity: {best_city_humidity}, starting from {best_start_date_humidity} with average humidity {best_average_humidity}")
print(f"Best week based on low wind speed: {best_city_wind_speed}, starting from {best_start_date_wind_speed} with average wind speed {best_average_wind_speed}")

# Save the combined forecast data to CSV
all_forecast_df.to_csv('all_forecast_filtered.csv', index=False)
# Out:
#        city        date  temp  humidity           condition  wind_speed
# 0    Athens  2024-06-05  28.7        33  Patchy rain nearby        19.1
# 1    Athens  2024-06-06  27.5        40               Sunny        15.1
# 2    Athens  2024-06-07  26.1        49  Patchy rain nearby        25.6
# 3    Athens  2024-06-08  26.0        40               Sunny        28.1
# 4    Athens  2024-06-09  26.3        34               Sunny        24.1
# 5    Athens  2024-06-10  26.7        34               Sunny        13.7
# 6    Athens  2024-06-11  29.1        38               Sunny        19.8
# 7    Athens  2024-06-12  30.6        30               Sunny        14.0
# 8    Athens  2024-06-13  29.4        38               Sunny        13.3
# 9    Athens  2024-06-14  28.5        46               Sunny        14.8
# 10    Corfu  2024-06-05  21.5        80  Patchy rain nearby        16.6
# 11    Corfu  2024-06-06  19.4        79  Patchy rain nearby        29.5
# 12    Corfu  2024-06-07  12.5        88       Moderate rain        20.9
# 13    Corfu  2024-06-08  13.6        86       Moderate rain        32.0
# 14    Corfu  2024-06-09  13.2        90       Moderate rain        22.3
# 15    Corfu  2024-06-10  12.4        87  Patchy rain nearby        19.4
# 16    Corfu  2024-06-11  15.5        76      Partly Cloudy         18.0
# 17    Corfu  2024-06-12  18.0        82  Patchy rain nearby        27.7
# 18    Corfu  2024-06-13  16.8        80      Partly Cloudy         16.6
# 19    Corfu  2024-06-14  17.9        74  Patchy rain nearby        26.3
# 20    Crete  2024-06-05  29.6        23               Sunny         8.6
# 21    Crete  2024-06-06  28.8        24               Sunny        11.2
# 22    Crete  2024-06-07  23.6        46  Patchy rain nearby        19.8
# 23    Crete  2024-06-08  22.9        47               Sunny        26.3
# 24    Crete  2024-06-09  22.8        40               Sunny        24.8
# 25    Crete  2024-06-10  25.0        34               Sunny        18.7
# 26    Crete  2024-06-11  29.4        30               Sunny        16.2
# 27    Crete  2024-06-12  30.9        22               Sunny        20.5
# 28    Crete  2024-06-13  29.3        25               Sunny        13.7
# 29    Crete  2024-06-14  29.5        22               Sunny        15.8
# 30    Zante  2024-06-05  16.0        64               Sunny        14.4
# 31    Zante  2024-06-06  13.9        64      Partly Cloudy         20.9
# 32    Zante  2024-06-07  12.0        68  Patchy rain nearby        16.9
# 33    Zante  2024-06-08  13.0        68      Partly Cloudy         16.9
# 34    Zante  2024-06-09  14.1        67  Patchy rain nearby        21.6
# 35    Zante  2024-06-10  11.0        72               Sunny        23.0
# 36    Zante  2024-06-11  13.8        61               Sunny        14.0
# 37    Zante  2024-06-12  13.9        55      Partly Cloudy         14.0
# 38    Zante  2024-06-13  14.5        64               Sunny        17.6
# 39    Zante  2024-06-14  15.4        71  Patchy rain nearby        20.9
# 40  Mykonos  2024-06-05  25.6        66               Sunny        16.9
# 41  Mykonos  2024-06-06  23.9        74  Patchy rain nearby        39.2
# 42  Mykonos  2024-06-07  23.0        78               Sunny        55.8
# 43  Mykonos  2024-06-08  22.8        76               Sunny        52.6
# 44  Mykonos  2024-06-09  23.1        73               Sunny        50.0
# 45  Mykonos  2024-06-10  24.7        67               Sunny        34.6
# 46  Mykonos  2024-06-11  26.2        67               Sunny        14.4
# 47  Mykonos  2024-06-12  25.7        71               Sunny        23.8
# 48  Mykonos  2024-06-13  24.6        76               Sunny        23.0
# 49  Mykonos  2024-06-14  24.2        75               Sunny        26.6
# Best week based on high temperature: Athens, starting from 2024-06-08 with average temp 28.085714285714285
# Best week based on low humidity: Crete, starting from 2024-06-08 with average humidity 31.428571428571427
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 102
#     100 print(f"Best week based on high temperature: {best_city_temp}, starting from {best_start_date_temp} with average temp {best_average_temp}")
#     101 print(f"Best week based on low humidity: {best_city_humidity}, starting from {best_start_date_humidity} with average humidity {best_average_humidity}")
# --> 102 print(f"Best week based on low wind speed: {best_city_wind_speed}, starting from {best_start_date_wind_speed} with average wind speed {best_average_wind_speed}")
#     104 # Save the combined forecast data to CSV
#     105 all_forecast_df.to_csv('all_forecast_filtered.csv', index=False)
#
# NameError: name 'best_start_date_wind_speed' is not defined

# %%
## colourful table
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource, TableColumn, DataTable, HTMLTemplateFormatter
from bokeh.io import show
import pandas as pd
 
df = all_forecast_df
 
source = ColumnDataSource(df)
 
# Define the color function for temperature
color_mapper = {
    'low': 'mediumaquamarine',
    'medium': 'lightsalmon',
    'high': 'brown'
}
 
# Apply color based on temperature value
def apply_color(temp):
    if temp < 20:
        return color_mapper['low']
    elif 20 <= temp < 30:
        return color_mapper['medium']
    else:
        return color_mapper['high']
 
# Add a new column for color in the DataFrame
df['temp_color'] = df['temp'].apply(apply_color)
source = ColumnDataSource(df)
 
# HTML Template for coloring
temp_formatter = HTMLTemplateFormatter(template="""
<div style="background-color:<%= temp_color %>; color: white;">
<%= value %>
</div>
""")
 
columns = [
    TableColumn(field='city', title='city'),
    TableColumn(field='date', title='date'),
    TableColumn(field='temp', title='temp', formatter=temp_formatter),
    TableColumn(field='humidity', title='humidity'),
    TableColumn(field='condition', title='condition'),
    TableColumn(field='wind_speed', title='wind_speed')
]
 
myTable = DataTable(source=source, columns=columns)

# %%
##combining grabbing from URL and the table
import requests
import pandas as pd
from datetime import datetime
from bokeh.plotting import output_file, show
from bokeh.models import Select, Div, Button, CustomJS, ColumnDataSource
from bokeh.models.widgets import DateRangePicker, Paragraph
from bokeh.layouts import column, row
from bokeh.io import curdoc

# WeatherAPI key
weather_key = "11da115d9a8d4556bd993522240506"

# Function to fetch weather data from WeatherAPI
def fetch_weather_data(city, weather_key):
    base_url = 'http://api.weatherapi.com/v1'
    url = f"{base_url}/forecast.json?key={weather_key}&q={city}&days=10"
    response = requests.get(url)
    data = response.json()
    return data

# Output to a new HTML file
output_file("index.html")

# Create Select for city input with the cities from the CSV
#city_select = Select(title="City:", value=cities[0], options=cities)

# Create a Button to update the recommended dates
update_button = Button(label="Discover this city", css_classes=['custom-button'])

# Create a DateRangePicker widget
date_range_picker = DateRangePicker(title="Select a date range:")

# Create a Paragraph to show recommended dates
recommended_dates_text = Paragraph(text="According to the weather crystal ball, your recommended dates are: ")

# Create a Div element for displaying the selected city and date range
result_div = Div()

# Display the logo image using IPython.display.Image
logo_image = Div(text="<img src='sunnylogo.png' style='width:100px;height:100px;'>")

# Create a Div for the title with custom CSS style for the font and background color
title_div = Div(text="<h1 style='font-family: Cooper Black, sans-serif; font-size: 36px; color: teal;'><center>Holidays by Sunny Side Up</center></h1>",
                sizing_mode='stretch_width', css_classes=['title-div'])

# Create a row layout for the header and the logo
header = row(logo_image, title_div)

# Function to handle city selection change
def update_selected_city(attr, old, new):
    result_div.text = f"Selected city: {new}"

# Function to handle button click to update the recommended dates
def update_recommended_dates():
    selected_city = city_select.value
    start_date, end_date = date_range_picker.value_as_datetime
    
    # Fetch weather data for the selected city
    data = fetch_weather_data(selected_city, weather_key)
    
    # Process the data as per your requirement
    if 'error' not in data:
        # Assuming you want to display some statistics or details about the selected city and date range
        # Extract relevant data from the API response
        forecast = data['forecast']['forecastday']
        
        # Example: Calculate average temperature and humidity from the forecast
        avg_temp = sum([day['day']['avgtemp_c'] for day in forecast]) / len(forecast)
        avg_humidity = sum([day['day']['avghumidity'] for day in forecast]) / len(forecast)
        
        # Update the recommended dates text
        recommended_dates_text.text = f"Avg. temperature: {avg_temp:.2f}°C<br>Avg. humidity: {avg_humidity:.2f}%"
        
    else:
        recommended_dates_text.text = f"No data available for {selected_city} in the selected date range."

# Function to handle date range picker change
def show_selected_date_range(attr, old, new):
    result_div.text = f"Selected city: {city_select.value}<br>Selected date range: {new[0]} to {new[1]}"

# Attach the functions to the button click events
update_button.on_click(update_recommended_dates)
date_range_picker.on_change('value', show_selected_date_range)

# Attach the function to the city select change event
city_select.on_change('value', update_selected_city)

df = all_forecast_df
 
source = ColumnDataSource(df)
 
# Define the color function for temperature
color_mapper = {
    'low': 'mediumaquamarine',
    'medium': 'lightsalmon',
    'high': 'brown'
}
 
# Apply color based on temperature value
def apply_color(temp):
    if temp < 20:
        return color_mapper['low']
    elif 20 <= temp < 30:
        return color_mapper['medium']
    else:
        return color_mapper['high']
 
# Add a new column for color in the DataFrame
df['temp_color'] = df['temp'].apply(apply_color)
source = ColumnDataSource(df)
 
# HTML Template for coloring
temp_formatter = HTMLTemplateFormatter(template="""
<div style="background-color:<%= temp_color %>; color: white;">
<%= value %>
</div>
""")
 
columns = [
    TableColumn(field='city', title='city'),
    TableColumn(field='date', title='date'),
    TableColumn(field='temp', title='temp', formatter=temp_formatter),
    TableColumn(field='humidity', title='humidity'),
    TableColumn(field='condition', title='condition'),
    TableColumn(field='wind_speed', title='wind_speed')
]
 
myTable = DataTable(source=source, columns=columns)

# Layout the widgets initially with city input, button, and result div
inputs = column(city_select, date_range_picker, update_button)
results = column(recommended_dates_text, myTable, result_div)
layout = column(header, inputs, results, sizing_mode='stretch_both', css_classes=['app-layout'])

# Display the plot
show(layout)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 137
#     134 layout = column(header, inputs, results, sizing_mode='stretch_both', css_classes=['app-layout'])
#     136 # Display the plot
# --> 137 show(layout)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\bokeh\io\showing.py:149, in show(obj, browser, new, notebook_handle, notebook_url, **kwargs)
#     146 state = curstate()
#     148 if isinstance(obj, UIElement):
# --> 149     return _show_with_state(obj, state, browser, new, notebook_handle=notebook_handle)
#     151 def is_application(obj: Any) -> TypeGuard[Application]:
#     152     return getattr(obj, '_is_a_bokeh_application_class', False)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\bokeh\io\showing.py:200, in _show_with_state(obj, state, browser, new, notebook_handle)
#     197     shown = True
#     199 if state.file or not shown:
# --> 200     _show_file_with_state(obj, state, new, controller)
#     202 return comms_handle
#
# File C:\ProgramData\anaconda3\Lib\site-packages\bokeh\io\showing.py:181, in _show_file_with_state(obj, state, new, controller)
#     177 def _show_file_with_state(obj: UIElement, state: State, new: BrowserTarget, controller: BrowserLike) -> None:
#     178     '''
#     179
#     180     '''
# --> 181     filename = save(obj, state=state)
#     182     controller.open("file://" + filename, new=NEW_PARAM[new])
#
# File C:\ProgramData\anaconda3\Lib\site-packages\bokeh\io\saving.py:98, in save(obj, filename, resources, title, template, state)
#      95 theme = state.document.theme
#      97 filename, resources, title = _get_save_args(state, filename, resources, title)
# ---> 98 _save_helper(obj, filename, resources, title, template, theme)
#      99 return abspath(expanduser(filename))
#
# File C:\ProgramData\anaconda3\Lib\site-packages\bokeh\io\saving.py:164, in _save_helper(obj, filename, resources, title, template, theme)
#     160 '''
#     161
#     162 '''
#     163 from ..embed import file_html
# --> 164 html = file_html(obj, resources=resources, title=title, template=template or FILE, theme=theme)
#     166 with open(filename, mode="w", encoding="utf-8") as f:
#     167     f.write(html)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\bokeh\embed\standalone.py:358, in file_html(models, resources, title, template, template_variables, theme, suppress_callback_warning, _always_new)
#     354     models_seq = models
#     356 resources = Resources.build(resources)
# --> 358 with OutputDocumentFor(models_seq, apply_theme=theme, always_new=_always_new) as doc:
#     359     (docs_json, render_items) = standalone_docs_json_and_render_items(models_seq, suppress_callback_warning=suppress_callback_warning)
#     360     title = _title_from_models(models_seq, title)
#
# File C:\ProgramData\anaconda3\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File C:\ProgramData\anaconda3\Lib\site-packages\bokeh\embed\util.py:153, in OutputDocumentFor(objs, apply_theme, always_new)
#     151     doc = _new_doc()
#     152     for model in objs:
# --> 153         doc.add_root(model)
#     155 # handle a single shared document
#     156 elif len(docs) == 1:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\bokeh\document\document.py:321, in Document.add_root(self, model, setter)
#     318 if model in self._roots:
#     319     return
# --> 321 with self.models.freeze():
#     322     self._roots.append(model)
#     324 self.callbacks.trigger_on_change(RootAddedEvent(self, model, setter))
#
# File C:\ProgramData\anaconda3\Lib\contextlib.py:144, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     142 if typ is None:
#     143     try:
# --> 144         next(self.gen)
#     145     except StopIteration:
#     146         return False
#
# File C:\ProgramData\anaconda3\Lib\site-packages\bokeh\document\models.py:135, in DocumentModelManager.freeze(self)
#     133 self._push_freeze()
#     134 yield
# --> 135 self._pop_freeze()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\bokeh\document\models.py:288, in DocumentModelManager._pop_freeze(self)
#     286 self._freeze_count -= 1
#     287 if self._freeze_count == 0:
# --> 288     self.recompute()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\bokeh\document\models.py:235, in DocumentModelManager.recompute(self)
#     232     md._detach_document()
#     234 for ma in to_attach:
# --> 235     ma._attach_document(document)
#     236     self._new_models.add(ma)
#     238 self._models = recomputed
#
# File C:\ProgramData\anaconda3\Lib\site-packages\bokeh\model\model.py:582, in Model._attach_document(self, doc)
#     579     return
#     581 if self.document is not None:
# --> 582     raise RuntimeError(f"Models must be owned by only a single document, {self!r} is already in a doc")
#     584 doc.theme.apply_to_model(self)
#     585 self.document = doc
#
# RuntimeError: Models must be owned by only a single document, Select(id='p1001', ...) is already in a doc

# %%
### RESTARTING

##attempting to get from URL
import requests
import pandas as pd
from datetime import datetime
from bokeh.plotting import output_file, show
from bokeh.models import Select, Div, Button, CustomJS, ColumnDataSource
from bokeh.models.widgets import DateRangePicker, Paragraph
from bokeh.layouts import column, row
from bokeh.io import curdoc

# WeatherAPI key
weather_key = "11da115d9a8d4556bd993522240506"

# Function to fetch weather data from WeatherAPI
def fetch_weather_data(city, weather_key):
    base_url = 'http://api.weatherapi.com/v1'
    url = f"{base_url}/forecast.json?key={weather_key}&q={city}&days=10"
    response = requests.get(url)
    data = response.json()
    return data

# Read the CSV file
df = pd.read_csv('all_forecast.csv')

# Get unique city names from the CSV
cities = df['city'].unique().tolist()

# Output to a new HTML file
output_file("index.html")

# Create Select for city input with the cities from the CSV
city_select = Select(title="City:", value=cities[0], options=cities)

# Create a Button to update the recommended dates
update_button = Button(label="Discover this city", css_classes=['custom-button'])

# Create a DateRangePicker widget
date_range_picker = DateRangePicker(title="Select a date range:")

# Create a Paragraph to show recommended dates
recommended_dates_text = Paragraph(text="According to the weather crystal ball, your recommended dates are: ")

# Create a Div element for displaying the selected city and date range
result_div = Div()

# Display the logo image using IPython.display.Image
logo_image = Div(text="<img src='sunnylogo.png' style='width:100px;height:100px;'>")

# Create a Div for the title with custom CSS style for the font and background color
title_div = Div(text="<h1 style='font-family: Cooper Black, sans-serif; font-size: 36px; color: teal;'><center>Holidays by Sunny Side Up</center></h1>",
                sizing_mode='stretch_width', css_classes=['title-div'])

# Create a row layout for the header and the logo
header = row(logo_image, title_div)

# Function to handle city selection change
def update_selected_city(attr, old, new):
    result_div.text = f"Selected city: {new}"

# Function to handle button click to update the recommended dates
def update_recommended_dates():
    selected_city = city_select.value
    start_date, end_date = date_range_picker.value_as_datetime
    
    # Fetch weather data for the selected city
    data = fetch_weather_data(selected_city, weather_key)
    
    # Process the data as per your requirement
    if 'error' not in data:
        # Assuming you want to display some statistics or details about the selected city and date range
        # Extract relevant data from the API response
        forecast = data['forecast']['forecastday']
        
        # Example: Calculate average temperature and humidity from the forecast
        avg_temp = sum([day['day']['avgtemp_c'] for day in forecast]) / len(forecast)
        avg_humidity = sum([day['day']['avghumidity'] for day in forecast]) / len(forecast)
        
        # Update the recommended dates text
        recommended_dates_text.text = f"Avg. temperature: {avg_temp:.2f}°C<br>Avg. humidity: {avg_humidity:.2f}%"
        
    else:
        recommended_dates_text.text = f"No data available for {selected_city} in the selected date range."

# Function to handle date range picker change
def show_selected_date_range(attr, old, new):
    result_div.text = f"Selected city: {city_select.value}<br>Selected date range: {new[0]} to {new[1]}"

# Attach the functions to the button click events
update_button.on_click(update_recommended_dates)
date_range_picker.on_change('value', show_selected_date_range)

# Attach the function to the city select change event
city_select.on_change('value', update_selected_city)

# Layout the widgets initially with city input, button, and result div
inputs = column(city_select, date_range_picker, update_button)
results = column(recommended_dates_text, result_div)
layout = column(header, inputs, results, sizing_mode='stretch_both', css_classes=['app-layout'])

# Display the plot
show(layout)
# Out:
# WARNING:bokeh.embed.util:
# You are generating standalone HTML/JS output, but trying to use real Python
# callbacks (i.e. with on_change or on_event). This combination cannot work.
#
# Only JavaScript callbacks may be used with standalone output. For more
# information on JavaScript callbacks with Bokeh, see:
#
#     https://docs.bokeh.org/en/latest/docs/user_guide/interaction/callbacks.html
#
# Alternatively, to use real Python callbacks, a Bokeh server application may
# be used. For more information on building and running Bokeh applications, see:
#
#     https://docs.bokeh.org/en/latest/docs/user_guide/server.html

# %%
import requests
import pandas as pd
from datetime import datetime
from bokeh.plotting import output_file, show, curdoc
from bokeh.models import Select, Div, Button, ColumnDataSource
from bokeh.models.widgets import DateRangePicker, Paragraph, DataTable, TableColumn, HTMLTemplateFormatter
from bokeh.layouts import column, row

# WeatherAPI key
weather_key = "11da115d9a8d4556bd993522240506"

# Function to fetch weather data from WeatherAPI
def fetch_weather_data(city, weather_key):
    base_url = 'http://api.weatherapi.com/v1'
    url = f"{base_url}/forecast.json?key={weather_key}&q={city}&days=10"
    response = requests.get(url)
    data = response.json()
    return data

# Get unique city names directly from the WeatherAPI
def get_city_list():
    url = f"http://api.weatherapi.com/v1/search.json?key={weather_key}&q=Greece"
    response = requests.get(url)
    data = response.json()
    cities = [city['name'] for city in data]
    return cities

# Output to a new HTML file
output_file("index.html")

# Create Select for city input with the cities from the API
cities = get_city_list()
city_select = Select(title="City:", value=cities[0], options=cities)

# Create a Button to update the recommended dates and table
update_button = Button(label="Discover this city", css_classes=['custom-button'])

# Create a DateRangePicker widget
date_range_picker = DateRangePicker(title="Select a date range:")

# Create a Paragraph to show recommended dates
recommended_dates_text = Paragraph(text="According to the weather crystal ball, your recommended dates are: ")

# Create a Div element for displaying the selected city and date range
result_div = Div()

# Display the logo image using IPython.display.Image
logo_image = Div(text="<img src='sunnylogo.png' style='width:100px;height:100px;'>")

# Create a Div for the title with custom CSS style for the font and background color
title_div = Div(text="<h1 style='font-family: Cooper Black, sans-serif; font-size: 36px; color: teal;'><center>Holidays by Sunny Side Up</center></h1>",
                sizing_mode='stretch_width', css_classes=['title-div'])

# Create a row layout for the header and the logo
header = row(logo_image, title_div)

# Define the color function for temperature
color_mapper = {
    'low': 'mediumaquamarine',
    'medium': 'lightsalmon',
    'high': 'brown'
}

# Apply color based on temperature value
def apply_color(temp):
    if temp < 20:
        return color_mapper['low']
    elif 20 <= temp < 30:
        return color_mapper['medium']
    else:
        return color_mapper['high']

# Add a new column for color in the DataFrame
df = pd.DataFrame({
    'city': [],
    'date': [],
    'temp': [],
    'humidity': [],
    'condition': [],
    'wind_speed': []
})
df['temp_color'] = df['temp'].apply(apply_color)

# HTML Template for coloring
temp_formatter = HTMLTemplateFormatter(template="""
<div style="background-color:<%= temp_color %>; color: white;">
<%= value %>
</div>
""")

columns = [
    TableColumn(field='city', title='City'),
    TableColumn(field='date', title='Date'),
    TableColumn(field='temp', title='Temperature', formatter=temp_formatter),
    TableColumn(field='humidity', title='Humidity'),
    TableColumn(field='condition', title='Condition'),
    TableColumn(field='wind_speed', title='Wind Speed')
]

source = ColumnDataSource(df)
myTable = DataTable(source=source, columns=columns, width=800, height=280)

# Function to handle city selection change
def update_selected_city(attr, old, new):
    result_div.text = f"Selected city: {new}"

# Function to handle button click to update the recommended dates
def update_recommended_dates():
    selected_city = city_select.value
    start_date, end_date = date_range_picker.value_as_datetime
    
    # Fetch weather data for the selected city
    data = fetch_weather_data(selected_city, weather_key)
    
    # Process the data as per your requirement
    if 'error' not in data:
        # Assuming you want to display some statistics or details about the selected city and date range
        # Extract relevant data from the API response
        forecast = data['forecast']['forecastday']
        
        # Example: Calculate average temperature and humidity from the forecast
        avg_temp = sum([day['day']['avgtemp_c'] for day in forecast]) / len(forecast)
        avg_humidity = sum([day['day']['avghumidity'] for day in forecast]) / len(forecast)
        
        # Update the recommended dates text
        recommended_dates_text.text = f"Avg. temperature: {avg_temp:.2f}°C<br>Avg. humidity: {avg_humidity:.2f}%"
        
        # Update the DataTable with fetched data
        df = pd.DataFrame({
            'city': [selected_city] * len(forecast),
            'date': [day['date'] for day in forecast],
            'temp': [day['day']['avgtemp_c'] for day in forecast],
            'humidity': [day['day']['avghumidity'] for day in forecast],
            'condition': [day['day']['condition']['text'] for day in forecast],
            'wind_speed': [day['day']['maxwind_kph'] for day in forecast]
        })
        df['temp_color'] = df['temp'].apply(apply_color)
        source.data = ColumnDataSource(df).data
        
    else:
        recommended_dates_text.text = f"No data available for {selected_city} in the selected date range."

# Function to handle date range picker change
def show_selected_date_range(attr, old, new):
    result_div.text = f"Selected city: {city_select.value}<br>Selected date range: {new[0]} to {new[1]}"
    
    # Fetch weather data for the selected city
    selected_city = city_select.value
    data = fetch_weather_data(selected_city, weather_key)
    
    if 'error' not in data:
        # Update the DataTable with fetched data
        forecast = data['forecast']['forecastday']
        df = pd.DataFrame({
            'city': [selected_city] * len(forecast),
            'date': [day['date'] for day in forecast],
            'temp': [day['day']['avgtemp_c'] for day in forecast],
            'humidity': [day['day']['avghumidity'] for day in forecast],
            'condition': [day['day']['condition']['text'] for day in forecast],
            'wind_speed': [day['day']['maxwind_kph'] for day in forecast]
        })
        df['temp_color'] = df['temp'].apply(apply_color)
        source.data = ColumnDataSource(df).data
        
    else:
        recommended_dates_text.text = f"No data available for {selected_city} in the selected date range."

# Attach the functions to the button click events
update_button.on_click(update_recommended_dates)
date_range_picker.on_change('value', show_selected_date_range)
city_select.on_change('value', update_selected_city)

# Layout the widgets initially with city input, button, and result div
inputs = column(city_select, date_range_picker, update_button)
results = column(recommended_dates_text, result_div, myTable)
layout = column(header, inputs, results, sizing_mode='stretch_both', css_classes=['app-layout'])

# Display the plot
curdoc().add_root(layout)

show(layout)
# Out:
# WARNING:bokeh.embed.util:
# You are generating standalone HTML/JS output, but trying to use real Python
# callbacks (i.e. with on_change or on_event). This combination cannot work.
#
# Only JavaScript callbacks may be used with standalone output. For more
# information on JavaScript callbacks with Bokeh, see:
#
#     https://docs.bokeh.org/en/latest/docs/user_guide/interaction/callbacks.html
#
# Alternatively, to use real Python callbacks, a Bokeh server application may
# be used. For more information on building and running Bokeh applications, see:
#
#     https://docs.bokeh.org/en/latest/docs/user_guide/server.html

# %%
import requests
import pandas as pd
from datetime import datetime, timedelta

weather_key = "11da115d9a8d4556bd993522240506"

# Function to fetch weather data for the next 10 days for a single city
def fetch_10_day_forecast(city, api_key):
    base_url = 'http://api.weatherapi.com/v1'
    url = f"{base_url}/forecast.json?key={api_key}&q={city}&days=10"
    response = requests.get(url)
    data = response.json()
    
    # Check if the response contains the necessary forecast data
    if 'forecast' in data and 'forecastday' in data['forecast']:
        forecast_data = data['forecast']['forecastday']
        extracted_data = []
        
        for day in forecast_data:
            date = day['date']
            temp = day['day']['avgtemp_c']
            humidity = day['day']['avghumidity']
            cloudiness = day['day']['condition']['text']
            wind_speed = day['day']['maxwind_kph']
            
            extracted_data.append({
                'city': city,
                'date': date,
                'temp': temp,
                'humidity': humidity,
                'condition': cloudiness,
                'wind_speed': wind_speed
            })
        
        return pd.DataFrame(extracted_data)
    else:
        print(f"No forecast data available for {city}")
        return pd.DataFrame()

# Function to find the best 7 consecutive days based on specific filters
def find_best_7_days(forecast_df, criteria='temp'):
    best_city = None
    best_start_date = None
    best_average = float('-inf') if criteria == 'temp' else float('inf')
    
    for city in forecast_df['city'].unique():
        city_df = forecast_df[forecast_df['city'] == city]
        
        # Ensure the dates are sorted
        city_df = city_df.sort_values(by='date')
        
        # Iterate over possible 7-day windows
        for i in range(len(city_df) - 6):
            window = city_df.iloc[i:i+7]
            
            if criteria == 'temp':
                average = window['temp'].mean()
                if average > best_average:
                    best_average = average
                    best_city = city
                    best_start_date = window.iloc[0]['date']
            elif criteria == 'humidity':
                average = window['humidity'].mean()
                if average < best_average:
                    best_average = average
                    best_city = city
                    best_start_date = window.iloc[0]['date']
            elif criteria == 'wind_speed':
                average = window['wind_speed'].mean()
                if average < best_average:
                    best_average = average
                    best_city = city
                    best_start_date = window.iloc[0]['date']
    
    return best_city, best_start_date, best_average

# List of cities
cities = ['Athens', 'Corfu', 'Crete', 'Zante', 'Mykonos']

# API key
api_key = weather_key  # Replace with your actual API key

# Initialize an empty DataFrame to store the combined forecast data
all_forecast_df = pd.DataFrame()

# Loop through each city and fetch the forecast data
for city in cities:
    city_forecast_df = fetch_10_day_forecast(city, api_key)
    all_forecast_df = pd.concat([all_forecast_df, city_forecast_df], ignore_index=True)

# Display the combined DataFrame
display(all_forecast_df)

# Find the best 7 consecutive days for each criteria
best_city_temp, best_start_date_temp, best_average_temp = find_best_7_days(all_forecast_df, criteria='temp')
best_city_humidity, best_start_date_humidity, best_average_humidity = find_best_7_days(all_forecast_df, criteria='humidity')
best_city_wind_speed, best_all_forecast_dfstart_date_wind_speed, best_average_wind_speed = find_best_7_days(all_forecast_df, criteria='wind_speed')

print(f"Best week based on high temperature: {best_city_temp}, starting from {best_start_date_temp} with average temp {best_average_temp}")
print(f"Best week based on low humidity: {best_city_humidity}, starting from {best_start_date_humidity} with average humidity {best_average_humidity}")
print(f"Best week based on low wind speed: {best_city_wind_speed}, starting from {best_start_date_wind_speed} with average wind speed {best_average_wind_speed}")

# Save the combined forecast data to CSV
all_forecast_df.to_csv('all_forecast_filtered.csv', index=False)
# Out:
#        city        date  temp  humidity           condition  wind_speed
# 0    Athens  2024-06-05  28.7        33  Patchy rain nearby        19.1
# 1    Athens  2024-06-06  27.5        40               Sunny        15.1
# 2    Athens  2024-06-07  26.1        49  Patchy rain nearby        25.6
# 3    Athens  2024-06-08  26.0        40               Sunny        28.1
# 4    Athens  2024-06-09  26.3        34               Sunny        24.1
# 5    Athens  2024-06-10  26.7        34               Sunny        13.7
# 6    Athens  2024-06-11  29.1        38               Sunny        19.8
# 7    Athens  2024-06-12  30.6        30               Sunny        14.0
# 8    Athens  2024-06-13  29.4        38               Sunny        13.3
# 9    Athens  2024-06-14  28.5        46               Sunny        14.8
# 10    Corfu  2024-06-05  21.5        80  Patchy rain nearby        16.6
# 11    Corfu  2024-06-06  19.4        79  Patchy rain nearby        29.5
# 12    Corfu  2024-06-07  12.5        88       Moderate rain        20.9
# 13    Corfu  2024-06-08  13.6        86       Moderate rain        32.0
# 14    Corfu  2024-06-09  13.2        90       Moderate rain        22.3
# 15    Corfu  2024-06-10  12.4        87  Patchy rain nearby        19.4
# 16    Corfu  2024-06-11  15.5        76      Partly Cloudy         18.0
# 17    Corfu  2024-06-12  18.0        82  Patchy rain nearby        27.7
# 18    Corfu  2024-06-13  16.8        80      Partly Cloudy         16.6
# 19    Corfu  2024-06-14  17.9        74  Patchy rain nearby        26.3
# 20    Crete  2024-06-05  29.6        23               Sunny         8.6
# 21    Crete  2024-06-06  28.8        24               Sunny        11.2
# 22    Crete  2024-06-07  23.6        46  Patchy rain nearby        19.8
# 23    Crete  2024-06-08  22.9        47               Sunny        26.3
# 24    Crete  2024-06-09  22.8        40               Sunny        24.8
# 25    Crete  2024-06-10  25.0        34               Sunny        18.7
# 26    Crete  2024-06-11  29.4        30               Sunny        16.2
# 27    Crete  2024-06-12  30.9        22               Sunny        20.5
# 28    Crete  2024-06-13  29.3        25               Sunny        13.7
# 29    Crete  2024-06-14  29.5        22               Sunny        15.8
# 30    Zante  2024-06-05  16.0        64               Sunny        14.4
# 31    Zante  2024-06-06  13.9        64      Partly Cloudy         20.9
# 32    Zante  2024-06-07  12.0        68  Patchy rain nearby        16.9
# 33    Zante  2024-06-08  13.0        68      Partly Cloudy         16.9
# 34    Zante  2024-06-09  14.1        67  Patchy rain nearby        21.6
# 35    Zante  2024-06-10  11.0        72               Sunny        23.0
# 36    Zante  2024-06-11  13.8        61               Sunny        14.0
# 37    Zante  2024-06-12  13.9        55      Partly Cloudy         14.0
# 38    Zante  2024-06-13  14.5        64               Sunny        17.6
# 39    Zante  2024-06-14  15.4        71  Patchy rain nearby        20.9
# 40  Mykonos  2024-06-05  25.6        66               Sunny        16.9
# 41  Mykonos  2024-06-06  23.9        74  Patchy rain nearby        39.2
# 42  Mykonos  2024-06-07  23.0        78               Sunny        55.8
# 43  Mykonos  2024-06-08  22.8        76               Sunny        52.6
# 44  Mykonos  2024-06-09  23.1        73               Sunny        50.0
# 45  Mykonos  2024-06-10  24.7        67               Sunny        34.6
# 46  Mykonos  2024-06-11  26.2        67               Sunny        14.4
# 47  Mykonos  2024-06-12  25.7        71               Sunny        23.8
# 48  Mykonos  2024-06-13  24.6        76               Sunny        23.0
# 49  Mykonos  2024-06-14  24.2        75               Sunny        26.6
# Best week based on high temperature: Athens, starting from 2024-06-08 with average temp 28.085714285714285
# Best week based on low humidity: Crete, starting from 2024-06-08 with average humidity 31.428571428571427
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 101
#      99 print(f"Best week based on high temperature: {best_city_temp}, starting from {best_start_date_temp} with average temp {best_average_temp}")
#     100 print(f"Best week based on low humidity: {best_city_humidity}, starting from {best_start_date_humidity} with average humidity {best_average_humidity}")
# --> 101 print(f"Best week based on low wind speed: {best_city_wind_speed}, starting from {best_start_date_wind_speed} with average wind speed {best_average_wind_speed}")
#     103 # Save the combined forecast data to CSV
#     104 all_forecast_df.to_csv('all_forecast_filtered.csv', index=False)
#
# NameError: name 'best_start_date_wind_speed' is not defined

# %%
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource, TableColumn, DataTable, HTMLTemplateFormatter
from bokeh.io import show
import pandas as pd

# Assuming all_forecast_df is your DataFrame
df = all_forecast_df

source = ColumnDataSource(df)

# Define the color function for temperature
def apply_temp_color(temp):
    if temp < 20:
        return 'mediumaquamarine'
    elif 20 <= temp < 30:
        return 'lightsalmon'
    else:
        return 'brown'

# Add a new column for temperature color in the DataFrame
df['temp_color'] = df['temp'].apply(apply_temp_color)

# Define the color function for condition
condition_mapper = {
    'Sunny': 'gold',
    'Partly cloudy': 'lightblue',
    'Cloudy': 'gray',
    'Rain': 'blue',
    'Clear': 'white'
}

def apply_condition_color(condition):
    return condition_mapper.get(condition, 'white')

# Add a new column for condition color in the DataFrame
df['condition_color'] = df['condition'].apply(apply_condition_color)

source = ColumnDataSource(df)

# HTML Template for coloring temperature
temp_formatter = HTMLTemplateFormatter(template="""
    <div style="background-color:<%= temp_color %>; color: white;">
        <%= value %>
    </div>
""")

# HTML Template for coloring condition
condition_formatter = HTMLTemplateFormatter(template="""
    <div style="background-color:<%= condition_color %>; color: black;">
        <%= value %>
    </div>
""")

columns = [
    TableColumn(field='city', title='city'),
    TableColumn(field='date', title='date'),
    TableColumn(field='temp', title='temp', formatter=temp_formatter),
    TableColumn(field='humidity', title='humidity'),
    TableColumn(field='condition', title='condition', formatter=condition_formatter),
    TableColumn(field='wind_speed', title='wind_speed')
]

myTable = DataTable(source=source, columns=columns)

show(myTable)

# %%
from bokeh.plotting import output_file, show
from bokeh.models import Select, Div, Button, CustomJS, ColumnDataSource
from bokeh.models.widgets import DateRangePicker, Paragraph
from bokeh.layouts import column, row
from bokeh.io import curdoc
import pandas as pd

# WeatherAPI key
weather_key = "11da115d9a8d4556bd993522240506"

# Function to fetch weather data from WeatherAPI
def fetch_weather_data(city, weather_key):
    base_url = 'http://api.weatherapi.com/v1'
    url = f"{base_url}/forecast.json?key={weather_key}&q={city}&days=10"
    response = requests.get(url)
    data = response.json()
    return data

# Get unique city names directly from the WeatherAPI
def get_city_list():
    url = f"http://api.weatherapi.com/v1/search.json?key={weather_key}&q=Greece"
    response = requests.get(url)
    data = response.json()
    cities = [city['name'] for city in data]
    return cities

# Output to a new HTML file
output_file("index.html")

# Read the CSV file
#df = pd.read_csv('all_forecast.csv')

# Get unique city names from the CSV
cities = df['city'].unique().tolist()

# Output to a new HTML file
output_file("index.html")

# Create Select for city input with the cities from the CSV
city_select = Select(title="City:", value=cities[0], options=cities)

# Create a Button to update the recommended dates
update_button = Button(label="Discover this city", css_classes=['custom-button'])

# Create a DateRangePicker widget
date_range_picker = DateRangePicker(title="Select a date range:")

# Create a Paragraph to show recommended dates
recommended_dates_text = Paragraph(text="According to the weather crystal ball, your recommended dates are: ")

# Create a Div element for displaying the selected city and date range
result_div = Div()

# Display the logo image using IPython.display.Image
logo_image = Div(text="<img src='sunnylogo.png' style='width:100px;height:100px;'>")

# Create a Div for the title with custom CSS style for the font and background color
title_div = Div(text="<h1 style='font-family: Cooper Black, sans-serif; font-size: 36px; color: teal;'><center>Holidays by Sunny Side Up</center></h1>",
                sizing_mode='stretch_width', css_classes=['title-div'])

# Create a row layout for the header and the logo
header = row(logo_image, title_div)

# Function to handle city selection change
def update_selected_city(attr, old, new):
    result_div.text = f"Selected city: {new}"

# Function to handle button click to update the recommended dates
def update_recommended_dates():
    selected_city = city_select.value
    start_date, end_date = date_range_picker.value_as_datetime
    filtered_df = df[(df['city'] == selected_city) & (df['date'] >= start_date) & (df['date'] <= end_date)]
    
    if not filtered_df.empty:
        # Assuming you want to display some statistics or details about the selected city and date range
        avg_temp = filtered_df['temp'].mean()
        avg_humidity = filtered_df['humidity'].mean()
        recommended_dates_text.text = f"Avg. temperature: {avg_temp:.2f}°C<br>Avg. humidity: {avg_humidity:.2f}%"
    else:
        recommended_dates_text.text = f"No data available for {selected_city} in the selected date range."

# Function to handle date range picker change
def show_selected_date_range(attr, old, new):
    result_div.text = f"Selected city: {city_select.value}<br>Selected date range: {new[0]} to {new[1]}"

# Attach the functions to the button click events
update_button.on_click(update_recommended_dates)
date_range_picker.on_change('value', show_selected_date_range)

# Attach the function to the city select change event
city_select.on_change('value', update_selected_city)

# Layout the widgets initially with city input, button, and result div
inputs = column(city_select, recommended_dates_text, date_range_picker, update_button, myTable, result_div)

# Set the background color for the whole layout
layout = column(header, inputs, sizing_mode='stretch_both', css_classes=['app-layout'])


# Display the plot
show(layout)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 101
#      97 layout = column(header, inputs, sizing_mode='stretch_both', css_classes=['app-layout'])
#     100 # Display the plot
# --> 101 show(layout)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\bokeh\io\showing.py:149, in show(obj, browser, new, notebook_handle, notebook_url, **kwargs)
#     146 state = curstate()
#     148 if isinstance(obj, UIElement):
# --> 149     return _show_with_state(obj, state, browser, new, notebook_handle=notebook_handle)
#     151 def is_application(obj: Any) -> TypeGuard[Application]:
#     152     return getattr(obj, '_is_a_bokeh_application_class', False)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\bokeh\io\showing.py:200, in _show_with_state(obj, state, browser, new, notebook_handle)
#     197     shown = True
#     199 if state.file or not shown:
# --> 200     _show_file_with_state(obj, state, new, controller)
#     202 return comms_handle
#
# File C:\ProgramData\anaconda3\Lib\site-packages\bokeh\io\showing.py:181, in _show_file_with_state(obj, state, new, controller)
#     177 def _show_file_with_state(obj: UIElement, state: State, new: BrowserTarget, controller: BrowserLike) -> None:
#     178     '''
#     179
#     180     '''
# --> 181     filename = save(obj, state=state)
#     182     controller.open("file://" + filename, new=NEW_PARAM[new])
#
# File C:\ProgramData\anaconda3\Lib\site-packages\bokeh\io\saving.py:98, in save(obj, filename, resources, title, template, state)
#      95 theme = state.document.theme
#      97 filename, resources, title = _get_save_args(state, filename, resources, title)
# ---> 98 _save_helper(obj, filename, resources, title, template, theme)
#      99 return abspath(expanduser(filename))
#
# File C:\ProgramData\anaconda3\Lib\site-packages\bokeh\io\saving.py:164, in _save_helper(obj, filename, resources, title, template, theme)
#     160 '''
#     161
#     162 '''
#     163 from ..embed import file_html
# --> 164 html = file_html(obj, resources=resources, title=title, template=template or FILE, theme=theme)
#     166 with open(filename, mode="w", encoding="utf-8") as f:
#     167     f.write(html)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\bokeh\embed\standalone.py:358, in file_html(models, resources, title, template, template_variables, theme, suppress_callback_warning, _always_new)
#     354     models_seq = models
#     356 resources = Resources.build(resources)
# --> 358 with OutputDocumentFor(models_seq, apply_theme=theme, always_new=_always_new) as doc:
#     359     (docs_json, render_items) = standalone_docs_json_and_render_items(models_seq, suppress_callback_warning=suppress_callback_warning)
#     360     title = _title_from_models(models_seq, title)
#
# File C:\ProgramData\anaconda3\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File C:\ProgramData\anaconda3\Lib\site-packages\bokeh\embed\util.py:153, in OutputDocumentFor(objs, apply_theme, always_new)
#     151     doc = _new_doc()
#     152     for model in objs:
# --> 153         doc.add_root(model)
#     155 # handle a single shared document
#     156 elif len(docs) == 1:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\bokeh\document\document.py:321, in Document.add_root(self, model, setter)
#     318 if model in self._roots:
#     319     return
# --> 321 with self.models.freeze():
#     322     self._roots.append(model)
#     324 self.callbacks.trigger_on_change(RootAddedEvent(self, model, setter))
#
# File C:\ProgramData\anaconda3\Lib\contextlib.py:144, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     142 if typ is None:
#     143     try:
# --> 144         next(self.gen)
#     145     except StopIteration:
#     146         return False
#
# File C:\ProgramData\anaconda3\Lib\site-packages\bokeh\document\models.py:135, in DocumentModelManager.freeze(self)
#     133 self._push_freeze()
#     134 yield
# --> 135 self._pop_freeze()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\bokeh\document\models.py:288, in DocumentModelManager._pop_freeze(self)
#     286 self._freeze_count -= 1
#     287 if self._freeze_count == 0:
# --> 288     self.recompute()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\bokeh\document\models.py:235, in DocumentModelManager.recompute(self)
#     232     md._detach_document()
#     234 for ma in to_attach:
# --> 235     ma._attach_document(document)
#     236     self._new_models.add(ma)
#     238 self._models = recomputed
#
# File C:\ProgramData\anaconda3\Lib\site-packages\bokeh\model\model.py:582, in Model._attach_document(self, doc)
#     579     return
#     581 if self.document is not None:
# --> 582     raise RuntimeError(f"Models must be owned by only a single document, {self!r} is already in a doc")
#     584 doc.theme.apply_to_model(self)
#     585 self.document = doc
#
# RuntimeError: Models must be owned by only a single document, StringEditor(id='p1023', ...) is already in a doc

# %%
import requests
import pandas as pd
from bokeh.plotting import output_file, show, curdoc
from bokeh.models import Select, Div, Button, ColumnDataSource
from bokeh.models.widgets import DateRangePicker, Paragraph, DataTable, TableColumn, HTMLTemplateFormatter
from bokeh.layouts import column, row

# WeatherAPI key
weather_key = "11da115d9a8d4556bd993522240506"

# Function to fetch weather data for the next 10 days for a single city
def fetch_10_day_forecast(city, api_key):
    base_url = 'http://api.weatherapi.com/v1'
    url = f"{base_url}/forecast.json?key={api_key}&q={city}&days=10"
    response = requests.get(url)
    data = response.json()
    
    # Check if the response contains the necessary forecast data
    if 'forecast' in data and 'forecastday' in data['forecast']:
        forecast_data = data['forecast']['forecastday']
        extracted_data = []
        
        for day in forecast_data:
            date = day['date']
            temp = day['day']['avgtemp_c']
            humidity = day['day']['avghumidity']
            cloudiness = day['day']['condition']['text']
            wind_speed = day['day']['maxwind_kph']
            
            extracted_data.append({
                'city': city,
                'date': date,
                'temp': temp,
                'humidity': humidity,
                'condition': cloudiness,
                'wind_speed': wind_speed
            })
        
        return pd.DataFrame(extracted_data)
    else:
        print(f"No forecast data available for {city}")
        return pd.DataFrame()

# Function to find the best 7 consecutive days based on specific filters
def find_best_7_days(forecast_df, criteria='temp'):
    best_city = None
    best_start_date = None
    best_average = float('-inf') if criteria == 'temp' else float('inf')
    
    for city in forecast_df['city'].unique():
        city_df = forecast_df[forecast_df['city'] == city]
        
        # Ensure the dates are sorted
        city_df = city_df.sort_values(by='date')
        
        # Iterate over possible 7-day windows
        for i in range(len(city_df) - 6):
            window = city_df.iloc[i:i+7]
            
            if criteria == 'temp':
                average = window['temp'].mean()
                if average > best_average:
                    best_average = average
                    best_city = city
                    best_start_date = window.iloc[0]['date']
            elif criteria == 'humidity':
                average = window['humidity'].mean()
                if average < best_average:
                    best_average = average
                    best_city = city
                    best_start_date = window.iloc[0]['date']
            elif criteria == 'wind_speed':
                average = window['wind_speed'].mean()
                if average < best_average:
                    best_average = average
                    best_city = city
                    best_start_date = window.iloc[0]['date']
    
    return best_city, best_start_date, best_average

# List of cities
cities = ['Athens', 'Corfu', 'Crete', 'Zante', 'Mykonos']

# API key
api_key = weather_key  # Replace with your actual API key

# Initialize an empty DataFrame to store the combined forecast data
all_forecast_df = pd.DataFrame()

# Loop through each city and fetch the forecast data
for city in cities:
    city_forecast_df = fetch_10_day_forecast(city, api_key)
    all_forecast_df = pd.concat([all_forecast_df, city_forecast_df], ignore_index=True)

# Function to apply color based on temperature
def apply_temp_color(temp):
    if temp < 20:
        return 'mediumaquamarine'
    elif 20 <= temp < 30:
        return 'lightsalmon'
    else:
        return 'brown'

# Function to apply color based on condition
condition_mapper = {
    'Sunny': 'gold',
    'Partly cloudy': 'lightblue',
    'Cloudy': 'gray',
    'Rain': 'blue',
    'Clear': 'white'
}

def apply_condition_color(condition):
    return condition_mapper.get(condition, 'white')

# Add columns for coloring
all_forecast_df['temp_color'] = all_forecast_df['temp'].apply(apply_temp_color)
all_forecast_df['condition_color'] = all_forecast_df['condition'].apply(apply_condition_color)

# Output to a new HTML file
output_file("index.html")

# Create Select for city input with the cities from the DataFrame
cities = all_forecast_df['city'].unique().tolist()
city_select = Select(title="City:", value=cities[0], options=cities)

# Create a Button to update the recommended dates and table
update_button = Button(label="Discover this city", css_classes=['custom-button'])

# Create a DateRangePicker widget
date_range_picker = DateRangePicker(title="Select a date range:")

# Create a Paragraph to show recommended dates
recommended_dates_text = Paragraph(text="According to the weather crystal ball, your recommended dates are: ")

# Create a Div element for displaying the selected city and date range
result_div = Div()

# Create a DataTable to display the forecast data
columns = [
    TableColumn(field='city', title='City'),
    TableColumn(field='date', title='Date'),
    TableColumn(field='temp', title='Temperature'),
    TableColumn(field='humidity', title='Humidity'),
    TableColumn(field='condition', title='Condition'),
    TableColumn(field='wind_speed', title='Wind Speed'),
]

source = ColumnDataSource(all_forecast_df)
data_table = DataTable(source=source, columns=columns, width=800, height=280)

# Function to handle city selection change
def update_selected_city(attr, old, new):
    result_div.text = f"Selected city: {new}"

# Function to handle button click to update the recommended dates
def update_recommended_dates():
    selected_city = city_select.value
    start_date, end_date = date_range_picker.value_as_datetime
    
    filtered_df = all_forecast_df[(all_forecast_df['city'] == selected_city) & 
                                  (all_forecast_df['date'] >= start_date) & 
                                  (all_forecast_df['date'] <= end_date)]
    
    if not filtered_df.empty:
        avg_temp = filtered_df['temp'].mean()
        avg_humidity = filtered_df['humidity'].mean()
        recommended_dates_text.text = f"Avg. temperature: {avg_temp:.2f}°C<br>Avg. humidity: {avg_humidity:.2f}%"
    else:
        recommended_dates_text.text = f"No data available for {selected_city} in the selected date range."

# Function to handle date range picker change
def show_selected_date_range(attr, old, new):
    result_div.text = f"Selected city: {city_select.value}<br>Selected date range: {new[0]} to {new[1]}"

# Attach the functions to the button click events
update_button.on_click(update_recommended_dates)
date_range_picker.on_change('value', show_selected_date_range)
city_select.on_change('value', update_selected_city)

# Layout the widgets initially with city input, button, and result div
inputs = column(city_select, date_range_picker, update_button)
results = column(recommended_dates_text, result_div, data_table)
layout = column(inputs, results, sizing_mode='stretch_both', css_classes=['app-layout'])

# Display the plot
show(layout)
# Out:
# WARNING:bokeh.embed.util:
# You are generating standalone HTML/JS output, but trying to use real Python
# callbacks (i.e. with on_change or on_event). This combination cannot work.
#
# Only JavaScript callbacks may be used with standalone output. For more
# information on JavaScript callbacks with Bokeh, see:
#
#     https://docs.bokeh.org/en/latest/docs/user_guide/interaction/callbacks.html
#
# Alternatively, to use real Python callbacks, a Bokeh server application may
# be used. For more information on building and running Bokeh applications, see:
#
#     https://docs.bokeh.org/en/latest/docs/user_guide/server.html

# %%
#### best one so far - BUT NO COLOURS!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

import requests
import pandas as pd
from bokeh.plotting import output_file, show
from bokeh.models import Select, Div, Button, ColumnDataSource
from bokeh.models.widgets import DateRangePicker, Paragraph, DataTable, TableColumn, HTMLTemplateFormatter
from bokeh.layouts import column, row
from bokeh.io import curdoc

# WeatherAPI key
weather_key = "11da115d9a8d4556bd993522240506"

# Function to fetch weather data for the next 10 days for a single city
def fetch_10_day_forecast(city, api_key):
    base_url = 'http://api.weatherapi.com/v1'
    url = f"{base_url}/forecast.json?key={api_key}&q={city}&days=10"
    response = requests.get(url)
    data = response.json()
    
    # Check if the response contains the necessary forecast data
    if 'forecast' in data and 'forecastday' in data['forecast']:
        forecast_data = data['forecast']['forecastday']
        extracted_data = []
        
        for day in forecast_data:
            date = day['date']
            temp = day['day']['avgtemp_c']
            humidity = day['day']['avghumidity']
            cloudiness = day['day']['condition']['text']
            wind_speed = day['day']['maxwind_kph']
            
            extracted_data.append({
                'city': city,
                'date': date,
                'temp': temp,
                'humidity': humidity,
                'condition': cloudiness,
                'wind_speed': wind_speed
            })
        
        return pd.DataFrame(extracted_data)
    else:
        print(f"No forecast data available for {city}")
        return pd.DataFrame()

# Function to find the best 7 consecutive days based on specific filters
def find_best_7_days(forecast_df, criteria='temp'):
    best_city = None
    best_start_date = None
    best_average = float('-inf') if criteria == 'temp' else float('inf')
    
    for city in forecast_df['city'].unique():
        city_df = forecast_df[forecast_df['city'] == city]
        
        # Ensure the dates are sorted
        city_df = city_df.sort_values(by='date')
        
        # Iterate over possible 7-day windows
        for i in range(len(city_df) - 6):
            window = city_df.iloc[i:i+7]
            
            if criteria == 'temp':
                average = window['temp'].mean()
                if average > best_average:
                    best_average = average
                    best_city = city
                    best_start_date = window.iloc[0]['date']
            elif criteria == 'humidity':
                average = window['humidity'].mean()
                if average < best_average:
                    best_average = average
                    best_city = city
                    best_start_date = window.iloc[0]['date']
            elif criteria == 'wind_speed':
                average = window['wind_speed'].mean()
                if average < best_average:
                    best_average = average
                    best_city = city
                    best_start_date = window.iloc[0]['date']
    
    return best_city, best_start_date, best_average

# List of cities
cities = ['Athens', 'Corfu', 'Crete', 'Zante', 'Mykonos']

# API key
api_key = weather_key  # Replace with your actual API key

# Initialize an empty DataFrame to store the combined forecast data
all_forecast_df = pd.DataFrame()

# Loop through each city and fetch the forecast data
for city in cities:
    city_forecast_df = fetch_10_day_forecast(city, api_key)
    all_forecast_df = pd.concat([all_forecast_df, city_forecast_df], ignore_index=True)

# Function to apply color based on temperature
def apply_temp_color(temp):
    if temp < 20:
        return 'mediumaquamarine'
    elif 20 <= temp < 30:
        return 'lightsalmon'
    else:
        return 'brown'

# Function to apply color based on condition
condition_mapper = {
    'Sunny': 'gold',
    'Partly cloudy': 'lightblue',
    'Cloudy': 'gray',
    'Rain': 'blue',
    'Clear': 'white'
}

def apply_condition_color(condition):
    return condition_mapper.get(condition, 'white')

# Add columns for coloring
all_forecast_df['temp_color'] = all_forecast_df['temp'].apply(apply_temp_color)
all_forecast_df['condition_color'] = all_forecast_df['condition'].apply(apply_condition_color)

# Output to a new HTML file
output_file("index.html")

# Create Select for city input with the cities from the DataFrame
cities = all_forecast_df['city'].unique().tolist()
city_select = Select(title="City:", value=cities[0], options=cities)

# Create a Button to update the recommended dates and table
update_button = Button(label="Discover this city", css_classes=['custom-button'])

# Create a DateRangePicker widget
date_range_picker = DateRangePicker(title="Select a date range:")

# Create a Paragraph to show recommended dates
recommended_dates_text = Paragraph(text="According to the weather crystal ball, your recommended dates are: ")

# Create a Div element for displaying the selected city and date range
result_div = Div()

# Create a DataTable to display the forecast data
columns = [
    TableColumn(field='city', title='City'),
    TableColumn(field='date', title='Date'),
    TableColumn(field='temp', title='Temperature'),
    TableColumn(field='humidity', title='Humidity'),
    TableColumn(field='condition', title='Condition'),
    TableColumn(field='wind_speed', title='Wind Speed'),
]

source = ColumnDataSource(all_forecast_df)
data_table = DataTable(source=source, columns=columns, width=800, height=280)

# Logo and header
logo_image = Div(text="<img src='sunnylogo.png' style='width:100px;height:100px;'>")
title_div = Div(text="<h1 style='font-family: Cooper Black, sans-serif; font-size: 36px; color: teal;'><center>Holidays by Sunny Side Up</center></h1>",
                sizing_mode='stretch_width')

# Function to handle city selection change
def update_selected_city(attr, old, new):
    result_div.text = f"Selected city: {new}"

# Function to handle button click to update the recommended dates
def update_recommended_dates():
    selected_city = city_select.value
    start_date, end_date = date_range_picker.value_as_datetime
    
    filtered_df = all_forecast_df[(all_forecast_df['city'] == selected_city) & 
                                  (all_forecast_df['date'] >= start_date) & 
                                  (all_forecast_df['date'] <= end_date)]
    
    if not filtered_df.empty:
        avg_temp = filtered_df['temp'].mean()
        avg_humidity = filtered_df['humidity'].mean()
        recommended_dates_text.text = f"Avg. temperature: {avg_temp:.2f}°C<br>Avg. humidity: {avg_humidity:.2f}%"
    else:
        recommended_dates_text.text = f"No data available for {selected_city} in the selected date range."

# Function to handle date range picker change
def show_selected_date_range(attr, old, new):
    result_div.text = f"Selected city: {city_select.value}<br>Selected date range: {new[0]} to {new[1]}"

# Attach the functions to the button click events
update_button.on_click(update_recommended_dates)
date_range_picker.on_change('value', show_selected_date_range)
city_select.on_change('value', update_selected_city)

# Layout the widgets with city input, button, and result div
inputs = column(city_select, date_range_picker, update_button)
header = column(logo_image, title_div)
results = column(recommended_dates_text, result_div, data_table)
layout = column(header, inputs, results, sizing_mode='stretch_both', css_classes=['app-layout'])

# Display the plot
show(layout)
# Out:
# WARNING:bokeh.embed.util:
# You are generating standalone HTML/JS output, but trying to use real Python
# callbacks (i.e. with on_change or on_event). This combination cannot work.
#
# Only JavaScript callbacks may be used with standalone output. For more
# information on JavaScript callbacks with Bokeh, see:
#
#     https://docs.bokeh.org/en/latest/docs/user_guide/interaction/callbacks.html
#
# Alternatively, to use real Python callbacks, a Bokeh server application may
# be used. For more information on building and running Bokeh applications, see:
#
#     https://docs.bokeh.org/en/latest/docs/user_guide/server.html

# %%
## BEST ONE SO FAR -- WITH COLOURS

import requests
import pandas as pd
from bokeh.plotting import output_file, show
from bokeh.models import Select, Div, Button, ColumnDataSource
from bokeh.models.widgets import DateRangePicker, Paragraph, DataTable, TableColumn, HTMLTemplateFormatter
from bokeh.layouts import column

# WeatherAPI key
weather_key = "11da115d9a8d4556bd993522240506"

# Function to fetch weather data for the next 10 days for a single city
def fetch_10_day_forecast(city, api_key):
    base_url = 'http://api.weatherapi.com/v1'
    url = f"{base_url}/forecast.json?key={api_key}&q={city}&days=10"
    response = requests.get(url)
    data = response.json()
    
    # Check if the response contains the necessary forecast data
    if 'forecast' in data and 'forecastday' in data['forecast']:
        forecast_data = data['forecast']['forecastday']
        extracted_data = []
        
        for day in forecast_data:
            date = day['date']
            temp = day['day']['avgtemp_c']
            humidity = day['day']['avghumidity']
            cloudiness = day['day']['condition']['text']
            wind_speed = day['day']['maxwind_kph']
            
            extracted_data.append({
                'city': city,
                'date': date,
                'temp': temp,
                'humidity': humidity,
                'condition': cloudiness,
                'wind_speed': wind_speed
            })
        
        return pd.DataFrame(extracted_data)
    else:
        print(f"No forecast data available for {city}")
        return pd.DataFrame()

# Function to find the best 7 consecutive days based on specific filters
def find_best_7_days(forecast_df, criteria='temp'):
    best_city = None
    best_start_date = None
    best_average = float('-inf') if criteria == 'temp' else float('inf')
    
    for city in forecast_df['city'].unique():
        city_df = forecast_df[forecast_df['city'] == city]
        
        # Ensure the dates are sorted
        city_df = city_df.sort_values(by='date')
        
        # Iterate over possible 7-day windows
        for i in range(len(city_df) - 6):
            window = city_df.iloc[i:i+7]
            
            if criteria == 'temp':
                average = window['temp'].mean()
                if average > best_average:
                    best_average = average
                    best_city = city
                    best_start_date = window.iloc[0]['date']
            elif criteria == 'humidity':
                average = window['humidity'].mean()
                if average < best_average:
                    best_average = average
                    best_city = city
                    best_start_date = window.iloc[0]['date']
            elif criteria == 'wind_speed':
                average = window['wind_speed'].mean()
                if average < best_average:
                    best_average = average
                    best_city = city
                    best_start_date = window.iloc[0]['date']
    
    return best_city, best_start_date, best_average

# List of cities
cities = ['Athens', 'Corfu', 'Crete', 'Zante', 'Mykonos']

# API key
api_key = weather_key  # Replace with your actual API key

# Initialize an empty DataFrame to store the combined forecast data
all_forecast_df = pd.DataFrame()

# Loop through each city and fetch the forecast data
for city in cities:
    city_forecast_df = fetch_10_day_forecast(city, api_key)
    all_forecast_df = pd.concat([all_forecast_df, city_forecast_df], ignore_index=True)

# Function to apply color based on temperature
def apply_temp_color(temp):
    if temp < 20:
        return 'mediumaquamarine'
    elif 20 <= temp < 30:
        return 'lightsalmon'
    else:
        return 'brown'

# Function to apply color based on condition
condition_mapper = {
    'Sunny': 'gold',
    'Partly cloudy': 'lightblue',
    'Cloudy': 'gray',
    'Rain': 'blue',
    'Clear': 'white'
}

def apply_condition_color(condition):
    return condition_mapper.get(condition, 'white')

# Add columns for coloring
all_forecast_df['temp_color'] = all_forecast_df['temp'].apply(apply_temp_color)
all_forecast_df['condition_color'] = all_forecast_df['condition'].apply(apply_condition_color)

# Output to a new HTML file
output_file("index.html")

# Create Select for city input with the cities from the DataFrame
cities = all_forecast_df['city'].unique().tolist()
city_select = Select(title="City:", value=cities[0], options=cities)

# Create a Button to update the recommended dates and table
update_button = Button(label="Discover this city", css_classes=['custom-button'])

# Create a DateRangePicker widget
date_range_picker = DateRangePicker(title="Select a date range:")

# Create a Paragraph to show recommended dates
recommended_dates_text = Paragraph(text="According to the weather crystal ball, your recommended dates are: ")

# Create a Div element for displaying the selected city and date range
result_div = Div()

# Define the HTML template for coloring temperature and condition
temp_formatter = HTMLTemplateFormatter(template="""
    <span style="color: black; background-color: <%= temp_color %>;"> 
        <%= value %>
    </span>
""")
condition_formatter = HTMLTemplateFormatter(template="""
    <span style="color: black; background-color: <%= condition_color %>;"> 
        <%= value %>
    </span>
""")

# Create a DataTable to display the forecast data
columns = [
    TableColumn(field='city', title='City'),
    TableColumn(field='date', title='Date'),
    TableColumn(field='temp', title='Temperature', formatter=temp_formatter),
    TableColumn(field='humidity', title='Humidity'),
    TableColumn(field='condition', title='Condition', formatter=condition_formatter),
    TableColumn(field='wind_speed', title='Wind Speed'),
]

source = ColumnDataSource(all_forecast_df)
data_table = DataTable(source=source, columns=columns, width=800, height=280)

# Logo and header
logo_image = Div(text="<img src='sunnylogo.png' style='width:100px;height:100px;'>")
title_div = Div(text="<h1 style='font-family: Cooper Black, sans-serif; font-size: 36px; color: teal;'><center>Holidays by Sunny Side Up</center></h1>",
                sizing_mode='stretch_width')

# Function to handle city selection change
def update_selected_city(attr, old, new):
    result_div.text = f"Selected city: {new}"

# Function to handle button click to update the recommended dates
def update_recommended_dates():
    selected_city = city_select.value
    start_date, end_date = date_range_picker.value_as_datetime
    
    filtered_df = all_forecast_df[(all_forecast_df['city'] == selected_city) & 
                                  (all_forecast_df['date'] >= start_date) & 
                                  (all_forecast_df['date'] <= end_date)]
    
    if not filtered_df.empty:
        avg_temp = filtered_df['temp'].mean()
        avg_humidity = filtered_df['humidity'].mean()
        recommended_dates_text.text = f"Avg. temperature: {avg_temp:.2f}°C<br>Avg. humidity: {avg_humidity:.2f}%"
    else:
        recommended_dates_text.text = f"No data available for {selected_city} in the selected date range."

# Function to handle date range picker change
def show_selected_date_range(attr, old, new):
    result_div.text = f"Selected city: {city_select.value}<br>Selected date range: {new[0]} to {new[1]}"

# Attach the functions to the button click events
update_button.on_click(update_recommended_dates)
date_range_picker.on_change('value', show_selected_date_range)
city_select.on_change('value', update_selected_city)

# Layout the widgets with city input, button, and result div
inputs = column(city_select, date_range_picker, update_button)
header = column(logo_image, title_div)
results = column(recommended_dates_text, result_div, data_table)
layout = column(header, inputs, results, sizing_mode='stretch_both', css_classes=['app-layout'])

# Display the plot
show(layout)
# Out:
# WARNING:bokeh.embed.util:
# You are generating standalone HTML/JS output, but trying to use real Python
# callbacks (i.e. with on_change or on_event). This combination cannot work.
#
# Only JavaScript callbacks may be used with standalone output. For more
# information on JavaScript callbacks with Bokeh, see:
#
#     https://docs.bokeh.org/en/latest/docs/user_guide/interaction/callbacks.html
#
# Alternatively, to use real Python callbacks, a Bokeh server application may
# be used. For more information on building and running Bokeh applications, see:
#
#     https://docs.bokeh.org/en/latest/docs/user_guide/server.html

# %%
import requests
import pandas as pd
from bokeh.plotting import output_file, show
from bokeh.models import Select, Div, Button, ColumnDataSource
from bokeh.models.widgets import DateRangePicker, Paragraph, DataTable, TableColumn, HTMLTemplateFormatter
from bokeh.layouts import column

# WeatherAPI key
weather_key = "11da115d9a8d4556bd993522240506"

# Function to fetch weather data for the next 10 days for a single city
def fetch_10_day_forecast(city, api_key):
    base_url = 'http://api.weatherapi.com/v1'
    url = f"{base_url}/forecast.json?key={api_key}&q={city}&days=10"
    response = requests.get(url)
    data = response.json()
    
    # Check if the response contains the necessary forecast data
    if 'forecast' in data and 'forecastday' in data['forecast']:
        forecast_data = data['forecast']['forecastday']
        extracted_data = []
        
        for day in forecast_data:
            date = day['date']
            temp = day['day']['avgtemp_c']
            humidity = day['day']['avghumidity']
            cloudiness = day['day']['condition']['text']
            wind_speed = day['day']['maxwind_kph']
            
            extracted_data.append({
                'city': city,
                'date': date,
                'temp': temp,
                'humidity': humidity,
                'condition': cloudiness,
                'wind_speed': wind_speed
            })
        
        return pd.DataFrame(extracted_data)
    else:
        print(f"No forecast data available for {city}")
        return pd.DataFrame()

# Function to find the best 7 consecutive days based on specific filters
def find_best_7_days(forecast_df, criteria='temp'):
    best_city = None
    best_start_date = None
    best_average = float('-inf') if criteria == 'temp' else float('inf')
    
    for city in forecast_df['city'].unique():
        city_df = forecast_df[forecast_df['city'] == city]
        
        # Ensure the dates are sorted
        city_df = city_df.sort_values(by='date')
        
        # Iterate over possible 7-day windows
        for i in range(len(city_df) - 6):
            window = city_df.iloc[i:i+7]
            
            if criteria == 'temp':
                average = window['temp'].mean()
                if average > best_average:
                    best_average = average
                    best_city = city
                    best_start_date = window.iloc[0]['date']
            elif criteria == 'humidity':
                average = window['humidity'].mean()
                if average < best_average:
                    best_average = average
                    best_city = city
                    best_start_date = window.iloc[0]['date']
            elif criteria == 'wind_speed':
                average = window['wind_speed'].mean()
                if average < best_average:
                    best_average = average
                    best_city = city
                    best_start_date = window.iloc[0]['date']
    
    return best_city, best_start_date, best_average

# List of cities
cities = ['Athens', 'Corfu', 'Crete', 'Zante', 'Mykonos']

# API key
api_key = weather_key  # Replace with your actual API key

# Initialize an empty DataFrame to store the combined forecast data
all_forecast_df = pd.DataFrame()

# Loop through each city and fetch the forecast data
for city in cities:
    city_forecast_df = fetch_10_day_forecast(city, api_key)
    all_forecast_df = pd.concat([all_forecast_df, city_forecast_df], ignore_index=True)

# Function to apply color based on temperature
def apply_temp_color(temp):
    if temp < 20:
        return 'mediumaquamarine'
    elif 20 <= temp < 30:
        return 'lightsalmon'
    else:
        return 'brown'

# Function to apply color based on condition
condition_mapper = {
    'Sunny': 'gold',
    'Partly cloudy': 'lightblue',
    'Cloudy': 'gray',
    'Rain': 'blue',
    'Clear': 'white'
}

def apply_condition_color(condition):
    return condition_mapper.get(condition, 'white')

# Add columns for coloring
all_forecast_df['temp_color'] = all_forecast_df['temp'].apply(apply_temp_color)
all_forecast_df['condition_color'] = all_forecast_df['condition'].apply(apply_condition_color)

# Output to a new HTML file
output_file("index.html")

# Find the best 7 consecutive days for high temperature, low humidity, and low wind speed
best_city_temp, best_start_date_temp, best_average_temp = find_best_7_days(all_forecast_df, 'temp')
best_city_humidity, best_start_date_humidity, best_average_humidity = find_best_7_days(all_forecast_df, 'humidity')
best_city_wind_speed, best_start_date_wind_speed, best_average_wind_speed = find_best_7_days(all_forecast_df, 'wind_speed')

# Create a Paragraph to show recommended dates
recommended_dates_text = Paragraph(text=f"Best week based on high temperature: {best_city_temp}, starting from {best_start_date_temp} with average temp {best_average_temp}. "
                                       f"Best week based on low humidity: {best_city_humidity}, starting from {best_start_date_humidity} with average humidity {best_average_humidity}. "
                                       f"Best week based on low wind speed: {best_city_wind_speed}, starting from {best_start_date_wind_speed} with average wind speed {best_average_wind_speed}.",
                                  width=800, height=100)

# Create Select for city input with the cities from the DataFrame
cities = all_forecast_df['city'].unique().tolist()
city_select = Select(title="City:", value=cities[0], options=cities)

# Create a Button to update the recommended dates and table
update_button = Button(label="Discover this city", css_classes=['custom-button'])

# Create a DateRangePicker widget
date_range_picker = DateRangePicker(title="Select a date range:")

# Create a Div element for displaying the selected city and date range
result_div = Div()

# Create a DataTable to display the forecast data
columns = [
    TableColumn(field='city', title='City'),
    TableColumn(field='date', title='Date'),
    TableColumn(field='temp', title='Temperature'),
    TableColumn(field='humidity', title='Humidity'),
    TableColumn(field='condition', title='Condition'),
    TableColumn(field='wind_speed', title='Wind Speed'),
]

source = ColumnDataSource(all_forecast_df)
data_table = DataTable(source=source, columns=columns, width=800, height=280)

# Logo and header
logo_image = Div(text="<img src='sunnylogo.png' style='width:100px;height:100px;'>")
title_div = Div(text="<h1 style='font-family: Cooper Black, sans-serif; font-size: 36px; color: teal;'><center>Holidays by Sunny Side Up</center></h1>",
                sizing_mode='stretch_width')

# Function to handle city selection change
def update_selected_city(attr, old, new):
    result_div.text = f"Selected city: {new}"

# Function to handle button click to update the recommended dates
def update_recommended_dates():
    selected_city = city_select.value
    start_date, end_date = date_range_picker.value_as_datetime
    
    filtered_df = all_forecast_df[(all_forecast_df['city'] == selected_city) & 
                                  (all_forecast_df['date'] >= start_date) & 
                                  (all_forecast_df['date'] <= end_date)]
    
    if not filtered_df.empty:
        avg_temp = filtered_df['temp'].mean()
        avg_humidity = filtered_df['humidity'].mean()
        recommended_dates_text.text = f"Avg. temperature: {avg_temp:.2f}°C<br>Avg. humidity: {avg_humidity:.2f}%"
    else:
        recommended_dates_text.text = f"No data available for {selected_city} in the selected date range."

# Function to handle date range picker change
def show_selected_date_range(attr, old, new):
    result_div.text = f"Selected city: {city_select.value}<br>Selected date range: {new[0]} to {new[1]}"

# Attach the functions to the button click events
update_button.on_click(update_recommended_dates)
date_range_picker.on_change('value', show_selected_date_range)
city_select.on_change('value', update_selected_city)

# Layout the widgets with city input, button, and result div
inputs = column(city_select, date_range_picker, update_button)
header = column(logo_image, title_div)
results = column(recommended_dates_text, result_div, data_table)
layout = column(header, inputs, results, sizing_mode='stretch_both', css_classes=['app-layout'])

# Display the plot
show(layout)
# Out:
# WARNING:bokeh.embed.util:
# You are generating standalone HTML/JS output, but trying to use real Python
# callbacks (i.e. with on_change or on_event). This combination cannot work.
#
# Only JavaScript callbacks may be used with standalone output. For more
# information on JavaScript callbacks with Bokeh, see:
#
#     https://docs.bokeh.org/en/latest/docs/user_guide/interaction/callbacks.html
#
# Alternatively, to use real Python callbacks, a Bokeh server application may
# be used. For more information on building and running Bokeh applications, see:
#
#     https://docs.bokeh.org/en/latest/docs/user_guide/server.html

# %%
import requests
import pandas as pd
from bokeh.plotting import output_file, show
from bokeh.models import Select, Div, Button, ColumnDataSource, HTMLTemplateFormatter
from bokeh.models.widgets import DateRangePicker, Paragraph, DataTable, TableColumn
from bokeh.layouts import column

# WeatherAPI key
weather_key = "11da115d9a8d4556bd993522240506"

# Function to fetch weather data for the next 10 days for a single city
def fetch_10_day_forecast(city, api_key):
    base_url = 'http://api.weatherapi.com/v1'
    url = f"{base_url}/forecast.json?key={api_key}&q={city}&days=10"
    response = requests.get(url)
    data = response.json()
    
    # Check if the response contains the necessary forecast data
    if 'forecast' in data and 'forecastday' in data['forecast']:
        forecast_data = data['forecast']['forecastday']
        extracted_data = []
        
        for day in forecast_data:
            date = day['date']
            temp = day['day']['avgtemp_c']
            humidity = day['day']['avghumidity']
            cloudiness = day['day']['condition']['text']
            wind_speed = day['day']['maxwind_kph']
            
            extracted_data.append({
                'city': city,
                'date': date,
                'temp': temp,
                'humidity': humidity,
                'condition': cloudiness,
                'wind_speed': wind_speed
            })
        
        return pd.DataFrame(extracted_data)
    else:
        print(f"No forecast data available for {city}")
        return pd.DataFrame()

# Function to find the best 7 consecutive days based on specific filters
def find_best_7_days(forecast_df, criteria='temp'):
    best_city = None
    best_start_date = None
    best_average = float('-inf') if criteria == 'temp' else float('inf')
    
    for city in forecast_df['city'].unique():
        city_df = forecast_df[forecast_df['city'] == city]
        
        # Ensure the dates are sorted
        city_df = city_df.sort_values(by='date')
        
        # Iterate over possible 7-day windows
        for i in range(len(city_df) - 6):
            window = city_df.iloc[i:i+7]
            
            if criteria == 'temp':
                average = window['temp'].mean()
                if average > best_average:
                    best_average = average
                    best_city = city
                    best_start_date = window.iloc[0]['date']
            elif criteria == 'humidity':
                average = window['humidity'].mean()
                if average < best_average:
                    best_average = average
                    best_city = city
                    best_start_date = window.iloc[0]['date']
            elif criteria == 'wind_speed':
                average = window['wind_speed'].mean()
                if average < best_average:
                    best_average = average
                    best_city = city
                    best_start_date = window.iloc[0]['date']
    
    return best_city, best_start_date, best_average

# List of cities
cities = ['Athens', 'Corfu', 'Crete', 'Zante', 'Mykonos']

# API key
api_key = weather_key  # Replace with your actual API key

# Initialize an empty DataFrame to store the combined forecast data
all_forecast_df = pd.DataFrame()

# Loop through each city and fetch the forecast data
for city in cities:
    city_forecast_df = fetch_10_day_forecast(city, api_key)
    all_forecast_df = pd.concat([all_forecast_df, city_forecast_df], ignore_index=True)

# Function to apply color based on temperature
def apply_temp_color(temp):
    if temp < 20:
        return 'mediumaquamarine'
    elif 20 <= temp < 30:
        return 'lightsalmon'
    else:
        return 'brown'

# Function to apply color based on condition
condition_mapper = {
    'Sunny': 'gold',
    'Partly cloudy': 'lightblue',
    'Cloudy': 'gray',
    'Rain': 'blue',
    'Clear': 'white'
}

def apply_condition_color(condition):
    return condition_mapper.get(condition, 'white')

# Add columns for coloring
all_forecast_df['temp_color'] = all_forecast_df['temp'].apply(apply_temp_color)
all_forecast_df['condition_color'] = all_forecast_df['condition'].apply(apply_condition_color)

# Output to a new HTML file
output_file("index.html")

# Find the best 7 consecutive days for high temperature, low humidity, and low wind speed
best_city_temp, best_start_date_temp, best_average_temp = find_best_7_days(all_forecast_df, 'temp')
best_city_humidity, best_start_date_humidity, best_average_humidity = find_best_7_days(all_forecast_df, 'humidity')
best_city_wind_speed, best_start_date_wind_speed, best_average_wind_speed = find_best_7_days(all_forecast_df, 'wind_speed')

# Create a Paragraph to show recommended dates
recommended_dates_text = Paragraph(text=f"Best week based on high temperature: {best_city_temp}, starting from {best_start_date_temp} with average temp {best_average_temp}. "
                                       f"Best week based on low humidity: {best_city_humidity}, starting from {best_start_date_humidity} with average humidity {best_average_humidity}. "
                                       f"Best week based on low wind speed: {best_city_wind_speed}, starting from {best_start_date_wind_speed} with average wind speed {best_average_wind_speed}.",
                                  width=800, height=100)

# Create Select for city input with the cities from the DataFrame
cities = all_forecast_df['city'].unique().tolist()
city_select = Select(title="City:", value=cities[0], options=cities)

# Create a Button to update the recommended dates and table
update_button = Button(label="Discover this city", css_classes=['custom-button'])

# Create a DateRangePicker widget
date_range_picker = DateRangePicker(title="Select a date range:")

# Create a Div element for displaying the selected city and date range
result_div = Div()

# Create a DataTable to display the forecast data
columns = [
    TableColumn(field='city', title='City'),
    TableColumn(field='date', title='Date'),
    TableColumn(field='temp', title='Temperature', width=100, formatter=HTMLTemplateFormatter(template='<div style="background:<%= temp_color %>; color: black;"> <%= value %> </div>')),
    TableColumn(field='humidity', title='Humidity', width=100),
    TableColumn(field='condition', title='Condition', width=100, formatter=HTMLTemplateFormatter(template='<div style="background:<%= condition_color %>; color: black;"> <%= value %> </div>')),
    TableColumn(field='wind_speed', title='Wind Speed', width=100),
]

source = ColumnDataSource(all_forecast_df)
data_table = DataTable(source=source, columns=columns, width=800, height=280)

# Logo and header
logo_image = Div(text="<img src='sunnylogo.png' style='width:100px;height:100px;'>")
title_div = Div(text="<h1 style='font-family: Cooper Black, sans-serif; font-size: 36px; color: teal;'><center>Holidays by Sunny Side Up</center></h1>",
                sizing_mode='stretch_width')

# Function to handle city selection change
def update_selected_city(attr, old, new):
    result_div.text = f"Selected city: {new}"

# Function to handle button click to update the recommended dates
def update_recommended_dates():
    selected_city = city_select.value
    start_date, end_date = date_range_picker.value_as_datetime
    
    filtered_df = all_forecast_df[(all_forecast_df['city'] == selected_city) & 
                                  (all_forecast_df['date'] >= start_date) & 
                                  (all_forecast_df['date'] <= end_date)]
    
    if not filtered_df.empty:
        avg_temp = filtered_df['temp'].mean()
        avg_humidity = filtered_df['humidity'].mean()
        recommended_dates_text.text = f"Avg. temperature: {avg_temp:.2f}°C<br>Avg. humidity: {avg_humidity:.2f}%"
    else:
        recommended_dates_text.text = f"No data available for {selected_city} in the selected date range."

# Function to handle date range picker change
def show_selected_date_range(attr, old, new):
    result_div.text = f"Selected city: {city_select.value}<br>Selected date range: {new[0]} to {new[1]}"

# Attach the functions to the button click events
update_button.on_click(update_recommended_dates)
date_range_picker.on_change('value', show_selected_date_range)
city_select.on_change('value', update_selected_city)

# Layout the widgets with city input, button, and result div
inputs = column(city_select, date_range_picker, update_button)
header = column(logo_image, title_div)
results = column(recommended_dates_text, result_div, data_table)
layout = column(header, inputs, results, sizing_mode='stretch_both', css_classes=['app-layout'])





flight_data_table = DataTable(source=flight_source, columns=flight_columns, width=800, height=280)

# Display the plot
show(layout)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 129
#     126 best_city_wind_speed, best_start_date_wind_speed, best_average_wind_speed = find_best_7_days(all_forecast_df, 'wind_speed')
#     128 # Create a Paragraph to show recommended dates
# --> 129 recommended_dates_text = Paragraph(text=f"Best week based on high temperature: {best_city_temp}, starting from {best_start_date_temp} with average temp {best_average_temp}. "<br>
#     130                                        f"Best week based on low humidity: {best_city_humidity}, starting from {best_start_date_humidity} with average humidity {best_average_humidity}. "<br>
#     131                                        f"Best week based on low wind speed: {best_city_wind_speed}, starting from {best_start_date_wind_speed} with average wind speed {best_average_wind_speed}.",
#     132                                   width=800, height=100)
#     134 # Create Select for city input with the cities from the DataFrame
#     135 cities = all_forecast_df['city'].unique().tolist()
#
# NameError: name 'br' is not defined

# %%
### BEST ONE WITH COLOURS YAY - old

import requests
import pandas as pd
from bokeh.plotting import output_file, show
from bokeh.models import Select, Div, Button, ColumnDataSource, HTMLTemplateFormatter
from bokeh.models.widgets import DateRangePicker, Paragraph, DataTable, TableColumn
from bokeh.layouts import column

# WeatherAPI key
weather_key = "11da115d9a8d4556bd993522240506"

# Function to fetch weather data for the next 10 days for a single city
def fetch_10_day_forecast(city, api_key):
    base_url = 'http://api.weatherapi.com/v1'
    url = f"{base_url}/forecast.json?key={api_key}&q={city}&days=10"
    response = requests.get(url)
    data = response.json()
    
    # Check if the response contains the necessary forecast data
    if 'forecast' in data and 'forecastday' in data['forecast']:
        forecast_data = data['forecast']['forecastday']
        extracted_data = []
        
        for day in forecast_data:
            date = day['date']
            temp = day['day']['avgtemp_c']
            humidity = day['day']['avghumidity']
            cloudiness = day['day']['condition']['text']
            wind_speed = day['day']['maxwind_kph']
            
            extracted_data.append({
                'city': city,
                'date': date,
                'temp': temp,
                'humidity': humidity,
                'condition': cloudiness,
                'wind_speed': wind_speed
            })
        
        return pd.DataFrame(extracted_data)
    else:
        print(f"No forecast data available for {city}")
        return pd.DataFrame()

# Function to find the best 7 consecutive days based on specific filters
def find_best_7_days(forecast_df, criteria='temp'):
    best_city = None
    best_start_date = None
    best_average = float('-inf') if criteria == 'temp' else float('inf')
    
    for city in forecast_df['city'].unique():
        city_df = forecast_df[forecast_df['city'] == city]
        
        # Ensure the dates are sorted
        city_df = city_df.sort_values(by='date')
        
        # Iterate over possible 7-day windows
        for i in range(len(city_df) - 6):
            window = city_df.iloc[i:i+7]
            
            if criteria == 'temp':
                average = window['temp'].mean()
                if average > best_average:
                    best_average = average
                    best_city = city
                    best_start_date = window.iloc[0]['date']
            elif criteria == 'humidity':
                average = window['humidity'].mean()
                if average < best_average:
                    best_average = average
                    best_city = city
                    best_start_date = window.iloc[0]['date']
            elif criteria == 'wind_speed':
                average = window['wind_speed'].mean()
                if average < best_average:
                    best_average = average
                    best_city = city
                    best_start_date = window.iloc[0]['date']
    
    return best_city, best_start_date, best_average

# List of cities
cities = ['Athens', 'Corfu', 'Crete', 'Zante', 'Mykonos']

# API key
api_key = weather_key  # Replace with your actual API key

# Initialize an empty DataFrame to store the combined forecast data
all_forecast_df = pd.DataFrame()

# Loop through each city and fetch the forecast data
for city in cities:
    city_forecast_df = fetch_10_day_forecast(city, api_key)
    all_forecast_df = pd.concat([all_forecast_df, city_forecast_df], ignore_index=True)

# Function to apply color based on temperature
def apply_temp_color(temp):
    if temp < 20:
        return 'mediumaquamarine'
    elif 20 <= temp < 30:
        return 'lightsalmon'
    else:
        return 'brown'

# Function to apply color based on condition
condition_mapper = {
    'Sunny': 'gold',
    'Partly cloudy': 'lightblue',
    'Cloudy': 'gray',
    'Rain': 'blue',
    'Clear': 'white'
}

def apply_condition_color(condition):
    return condition_mapper.get(condition, 'white')

# Add columns for coloring
all_forecast_df['temp_color'] = all_forecast_df['temp'].apply(apply_temp_color)
all_forecast_df['condition_color'] = all_forecast_df['condition'].apply(apply_condition_color)

# Output to a new HTML file
output_file("index.html")

# Find the best 7 consecutive days for high temperature, low humidity, and low wind speed
best_city_temp, best_start_date_temp, best_average_temp = find_best_7_days(all_forecast_df, 'temp')
best_city_humidity, best_start_date_humidity, best_average_humidity = find_best_7_days(all_forecast_df, 'humidity')
best_city_wind_speed, best_start_date_wind_speed, best_average_wind_speed = find_best_7_days(all_forecast_df, 'wind_speed')

# Format best_average_temp, best_average_humidity, and best_average_wind_speed to 1 decimal place
best_average_temp_formatted = f"{best_average_temp:.1f}"
best_average_humidity_formatted = f"{best_average_humidity:.1f}"
best_average_wind_speed_formatted = f"{best_average_wind_speed:.1f}"

# Create a Div to show recommended dates
recommended_dates_temp = Div(text=f"<b>Best week based on high temperature:</b> {best_city_temp}, starting from {best_start_date_temp} with average temp {best_average_temp_formatted}°C.<br>",
                             width=800, height=50)

recommended_dates_humidity = Div(text=f"<b>Best week based on low humidity:</b> {best_city_humidity}, starting from {best_start_date_humidity} with average humidity {best_average_humidity_formatted}%.<br>",
                                 width=800, height=50)

recommended_dates_wind_speed = Div(text=f"<b>Best week based on low wind speed:</b> {best_city_wind_speed}, starting from {best_start_date_wind_speed} with average wind speed {best_average_wind_speed_formatted} kph.<br>",
                                  width=800, height=50)

# Create Select for city input with the cities from the DataFrame
cities = all_forecast_df['city'].unique().tolist()
city_select = Select(title="City:", value=cities[0], options=cities)

# Create a Button to update the recommended dates and table
update_button = Button(label="Discover this city", css_classes=['custom-button'])

# Create a DateRangePicker widget
date_range_picker = DateRangePicker(title="Select a date range:")

# Create a Div element for displaying the selected city and date range
result_div = Div()

# Create a DataTable to display the forecast data
columns = [
    TableColumn(field='city', title='City'),
    TableColumn(field='date', title='Date'),
    TableColumn(field='temp', title='Temperature', width=100, formatter=HTMLTemplateFormatter(template='<div style="background:<%= temp_color %>; color: black;"> <%= value %> </div>')),
    TableColumn(field='humidity', title='Humidity', width=100),
    TableColumn(field='condition', title='Condition', width=100, formatter=HTMLTemplateFormatter(template='<div style="background:<%= condition_color %>; color: black;"> <%= value %> </div>')),
    TableColumn(field='wind_speed', title='Wind Speed', width=100),
]

source = ColumnDataSource(all_forecast_df)
data_table = DataTable(source=source, columns=columns, width=800, height=280)

# Logo and header
logo_image = Div(text="<img src='sunnylogo.png' style='width:100px;height:100px;'>")
title_div = Div(text="<h1 style='font-family: Cooper Black, sans-serif; font-size: 36px; color: teal;'><center>Holidays by Sunny Side Up</center></h1>",
                sizing_mode='stretch_width')

# Function to handle city selection change
def update_selected_city(attr, old, new):
    result_div.text = f"Selected city: {new}"

# Function to handle button click to update the recommended dates
def update_recommended_dates():
    selected_city = city_select.value
    start_date, end_date = date_range_picker.value_as_datetime
    
    filtered_df = all_forecast_df[(all_forecast_df['city'] == selected_city) & 
                                  (all_forecast_df['date'] >= start_date) & 
                                  (all_forecast_df['date'] <= end_date)]
    
    if not filtered_df.empty:
        avg_temp = filtered_df['temp'].mean()
        avg_humidity = filtered_df['humidity'].mean()
        recommended_dates_text.text = f"Avg. temperature: {avg_temp:.2f}°C<br>Avg. humidity: {avg_humidity:.2f}%"
    else:
        recommended_dates_text.text = f"No data available for {selected_city} in the selected date range."

# Function to handle date range picker change
def show_selected_date_range(attr, old, new):
    result_div.text = f"Selected city: {city_select.value}<br>Selected date range: {new[0]} to {new[1]}"

# Attach the functions to the button click events
update_button.on_click(update_recommended_dates)
date_range_picker.on_change('value', show_selected_date_range)
city_select.on_change('value', update_selected_city)

# Layout the widgets with city input, button, and result div
inputs = column(city_select, date_range_picker, update_button)
header = column(logo_image, title_div)
results = column(recommended_dates_temp, recommended_dates_humidity, recommended_dates_wind_speed, result_div, data_table)
layout = column(header, inputs, results, sizing_mode='stretch_both', css_classes=['app-layout'])

# Display the plot
show(layout)
# Out:
# WARNING:bokeh.embed.util:
# You are generating standalone HTML/JS output, but trying to use real Python
# callbacks (i.e. with on_change or on_event). This combination cannot work.
#
# Only JavaScript callbacks may be used with standalone output. For more
# information on JavaScript callbacks with Bokeh, see:
#
#     https://docs.bokeh.org/en/latest/docs/user_guide/interaction/callbacks.html
#
# Alternatively, to use real Python callbacks, a Bokeh server application may
# be used. For more information on building and running Bokeh applications, see:
#
#     https://docs.bokeh.org/en/latest/docs/user_guide/server.html

# %%
## KEEEEEP

def get_airport_codes(city):
    api_url = 'https://api.api-ninjas.com/v1/airports?city={}'.format(city)
    headers = {'X-Api-Key': 'nrc3S/XZWbfao3LeySY9hg==I1u1i9JSOP6NSPFw'}
 
    response = requests.get(api_url, headers=headers)
    if response.status_code == requests.codes.ok:
        airport_data = response.json()
        airport_dict = {}  # Initialize an empty dictionary to store airport codes and names
        for airport in airport_data:
            airport_code = airport.get('iata')
            if airport_code:  # Check if airport code is not empty
                airport_name = airport.get('name')
                airport_dict[airport_code] = airport_name  # Add airport code and name to the dictionary
        return list(airport_dict.keys())  # Return a list of airport codes
    else:
        print("Error:", response.status_code, response.text)
 
 
airport_codes = get_airport_codes(cities[0])
'''
if airport_codes:
    print("Airport codes in", city + ":", airport_codes)
else:
    print("No airport codes found for", city)
'''
# Out:
# Airport codes in Mykonos: ['AHN', 'HEW', 'ATH']

# %%
## KEEEEEEP
# Create Select for city input with Greek cities
city_select = Select(title="City:", value="Athens", options=list(airport_codes.keys()))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Create Select for city input with Greek cities
# ----> 2 city_select = Select(title="City:", value="Athens", options=list(airport_codes.keys()))
#
# AttributeError: 'list' object has no attribute 'keys'

# %%
### KEEEEEEEEEEEP
import requests
import pandas as pd
from bokeh.plotting import output_file, show
from bokeh.models import Select, Div, Button, ColumnDataSource, HTMLTemplateFormatter
from bokeh.models.widgets import DateRangePicker, DataTable, TableColumn
from bokeh.layouts import column

# WeatherAPI key
weather_key = "11da115d9a8d4556bd993522240506"

# Function to fetch weather data for the next 10 days for a single city
def fetch_10_day_forecast(city, api_key):
    base_url = 'http://api.weatherapi.com/v1'
    url = f"{base_url}/forecast.json?key={api_key}&q={city}&days=10"
    response = requests.get(url)
    data = response.json()
    
    # Check if the response contains the necessary forecast data
    if 'forecast' in data and 'forecastday' in data['forecast']:
        forecast_data = data['forecast']['forecastday']
        extracted_data = []
        
        for day in forecast_data:
            date = day['date']
            temp = day['day']['avgtemp_c']
            humidity = day['day']['avghumidity']
            cloudiness = day['day']['condition']['text']
            wind_speed = day['day']['maxwind_kph']
            
            extracted_data.append({
                'city': city,
                'date': date,
                'temp': temp,
                'humidity': humidity,
                'condition': cloudiness,
                'wind_speed': wind_speed
            })
        
        return pd.DataFrame(extracted_data)
    else:
        print(f"No forecast data available for {city}")
        return pd.DataFrame()

# Function to find the best 7 consecutive days based on specific filters
def find_best_7_days(forecast_df, criteria='temp'):
    best_city = None
    best_start_date = None
    best_average = float('-inf') if criteria == 'temp' else float('inf')
    
    for city in forecast_df['city'].unique():
        city_df = forecast_df[forecast_df['city'] == city]
        
        # Ensure the dates are sorted
        city_df = city_df.sort_values(by='date')
        
        # Iterate over possible 7-day windows
        for i in range(len(city_df) - 6):
            window = city_df.iloc[i:i+7]
            
            if criteria == 'temp':
                average = window['temp'].mean()
                if average > best_average:
                    best_average = average
                    best_city = city
                    best_start_date = window.iloc[0]['date']
            elif criteria == 'humidity':
                average = window['humidity'].mean()
                if average < best_average:
                    best_average = average
                    best_city = city
                    best_start_date = window.iloc[0]['date']
            elif criteria == 'wind_speed':
                average = window['wind_speed'].mean()
                if average < best_average:
                    best_average = average
                    best_city = city
                    best_start_date = window.iloc[0]['date']
    
    return best_city, best_start_date, best_average

# Function to get airport codes based on city
def get_airport_codes(city):
    api_url = f'https://api.api-ninjas.com/v1/airports?city={city}'
    headers = {'X-Api-Key': 'nrc3S/XZWbfao3LeySY9hg==I1u1i9JSOP6NSPFw'}
 
    response = requests.get(api_url, headers=headers)
    if response.status_code == requests.codes.ok:
        airport_data = response.json()
        airport_dict = {}
        for airport in airport_data:
            airport_code = airport.get('iata')
            if airport_code:
                airport_name = airport.get('name')
                airport_dict[airport_code] = airport_name
        return list(airport_dict.keys())
    else:
        print("Error:", response.status_code, response.text)
        return []

# List of cities
cities = ['Athens', 'Corfu', 'Crete', 'Zante', 'Mykonos']

# API key
api_key = weather_key

# Initialize an empty DataFrame to store the combined forecast data
all_forecast_df = pd.DataFrame()

# Loop through each city and fetch the forecast data
for city in cities:
    city_forecast_df = fetch_10_day_forecast(city, api_key)
    all_forecast_df = pd.concat([all_forecast_df, city_forecast_df], ignore_index=True)

# Function to apply color based on temperature
def apply_temp_color(temp):
    if temp < 20:
        return 'mediumaquamarine'
    elif 20 <= temp < 30:
        return 'lightsalmon'
    else:
        return 'brown'

# Function to apply color based on condition
condition_mapper = {
    'Sunny': 'gold',
    'Partly cloudy': 'lightblue',
    'Cloudy': 'gray',
    'Rain': 'blue',
    'Clear': 'white'
}

def apply_condition_color(condition):
    return condition_mapper.get(condition, 'white')

# Add columns for coloring
all_forecast_df['temp_color'] = all_forecast_df['temp'].apply(apply_temp_color)
all_forecast_df['condition_color'] = all_forecast_df['condition'].apply(apply_condition_color)

# Output to a new HTML file
output_file("index.html")

# Find the best 7 consecutive days for high temperature, low humidity, and low wind speed
best_city_temp, best_start_date_temp, best_average_temp = find_best_7_days(all_forecast_df, 'temp')
best_city_humidity, best_start_date_humidity, best_average_humidity = find_best_7_days(all_forecast_df, 'humidity')
best_city_wind_speed, best_start_date_wind_speed, best_average_wind_speed = find_best_7_days(all_forecast_df, 'wind_speed')

# Format best_average_temp, best_average_humidity, and best_average_wind_speed to 1 decimal place
best_average_temp_formatted = f"{best_average_temp:.1f}"
best_average_humidity_formatted = f"{best_average_humidity:.1f}"
best_average_wind_speed_formatted = f"{best_average_wind_speed:.1f}"

# Create a Div to show recommended dates
recommended_dates_temp = Div(text=f"<b>Best week based on high temperature:</b> {best_city_temp}, starting from {best_start_date_temp} with average temp {best_average_temp_formatted}°C.<br>",
                             width=800, height=50)

recommended_dates_humidity = Div(text=f"<b>Best week based on low humidity:</b> {best_city_humidity}, starting from {best_start_date_humidity} with average humidity {best_average_humidity_formatted}%.<br>",
                                 width=800, height=50)

recommended_dates_wind_speed = Div(text=f"<b>Best week based on low wind speed:</b> {best_city_wind_speed}, starting from {best_start_date_wind_speed} with average wind speed {best_average_wind_speed_formatted} kph.<br>",
                                  width=800, height=50)

# Create Select for city input with the cities from the DataFrame
cities = all_forecast_df['city'].unique().tolist()
city_select = Select(title="City:", value=cities[0], options=cities)

# Get initial airport codes
initial_airport_codes = get_airport_codes(cities[0])
airport_select = Select(title="Airport:", value=initial_airport_codes[0] if initial_airport_codes else '', options=initial_airport_codes)

# Create a Button to update the recommended dates and table
update_button = Button(label="Discover this city", css_classes=['custom-button'])

# Create a DateRangePicker widget
date_range_picker = DateRangePicker(title="Select a date range:")

# Create a Div element for displaying the selected city and date range
result_div = Div()

# Create a DataTable to display the forecast data
columns = [
    TableColumn(field='city', title='City'),
    TableColumn(field='date', title='Date'),
    TableColumn(field='temp', title='Temperature', width=100, formatter=HTMLTemplateFormatter(template='<div style="background:<%= temp_color %>; color: black;"> <%= value %> </div>')),
    TableColumn(field='humidity', title='Humidity', width=100),
    TableColumn(field='condition', title='Condition', width=100, formatter=HTMLTemplateFormatter(template='<div style="background:<%= condition_color %>; color: black;"> <%= value %> </div>')),
    TableColumn(field='wind_speed', title='Wind Speed', width=100),
]

source = ColumnDataSource(all_forecast_df)
data_table = DataTable(source=source, columns=columns, width=800, height=280)

# Logo and header
logo_image = Div(text="<img src='sunnylogo.png' style='width:100px;height:100px;'>")
title_div = Div(text="<h1 style='font-family: Cooper Black, sans-serif; font-size: 36px; color: teal;'><center>Holidays by Sunny Side Up</center></h1>",
                sizing_mode='stretch_width')

# Function to handle city selection change
def update_selected_city(attr, old, new):
    # Update the airport select options based on the new city
    airport_codes = get_airport_codes(new)
    airport_select.options = airport_codes
    airport_select.value = airport_codes[0] if airport_codes else ''

    result_div.text = f"Selected city: {new}"

# Function to handle button click to update the recommended dates
def update_recommended_dates():
    selected_city = city_select.value
    start_date, end_date = date_range_picker.value_as_datetime
    
    filtered_df = all_forecast_df[(all_forecast_df['city'] == selected_city) & 
                                  (all_forecast_df['date'] >= start_date) & 
                                  (all_forecast_df['date'] <= end_date)]
    
    if not filtered_df.empty:
        avg_temp = filtered_df['temp'].mean()
        avg_humidity = filtered_df['humidity'].mean()
        result_div.text = f"Avg. temperature: {avg_temp:.2f}°C<br>Avg. humidity: {avg_humidity:.2f}%"
    else:
        result_div.text = f"No data available for {selected_city} in the selected date range."

# Function to handle date range picker change
def show_selected_date_range(attr, old, new):
    result_div.text = f"Selected city: {city_select.value}<br>Selected date range: {new[0]} to {new[1]}"





flight_source = ColumnDataSource(df)
flight_columns = [
    TableColumn(field='DepartureAirport', title='Departure Airport'),
    TableColumn(field='ArrivalAirport', title='Arrival Airport'),
    TableColumn(field='DepartureTime', title='Departure Time'),
    TableColumn(field='ArrivalTime', title='Arrival Time'),
    TableColumn(field='Duration(hours)', title='Duration (hours)'),
    TableColumn(field='PriceWithCurrency', title='Price')
]

flight_data_table = DataTable(source=flight_source, columns=flight_columns, width=800, height=280)

# Attach the functions to the button click events
update_button.on_click(update_recommended_dates)
date_range_picker.on_change('value', show_selected_date_range)
originLocationCode = city_select.on_change('value', update_selected_city)

# Layout the widgets with city input, button, and result div
inputs = column(city_select, airport_select, date_range_picker, update_button)
header = column(logo_image, title_div)
results = column(recommended_dates_temp, recommended_dates_humidity, recommended_dates_wind_speed, result_div, data_table,flight_data_table)
layout = column(header, inputs, results, sizing_mode='stretch_both', css_classes=['app-layout'])



# Display the plot
show(layout)
# Out:
# WARNING:bokeh.embed.util:
# You are generating standalone HTML/JS output, but trying to use real Python
# callbacks (i.e. with on_change or on_event). This combination cannot work.
#
# Only JavaScript callbacks may be used with standalone output. For more
# information on JavaScript callbacks with Bokeh, see:
#
#     https://docs.bokeh.org/en/latest/docs/user_guide/interaction/callbacks.html
#
# Alternatively, to use real Python callbacks, a Bokeh server application may
# be used. For more information on building and running Bokeh applications, see:
#
#     https://docs.bokeh.org/en/latest/docs/user_guide/server.html

# %%
pip install amadeus
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: amadeus in c:\users\semaguler\appdata\roaming\python\python311\site-packages (10.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
def get_access_token():
    url = "https://test.api.amadeus.com/v1/security/oauth2/token"
    headers = {
        "Content-Type": "application/x-www-form-urlencoded"
    }
    data = {
        "grant_type": "client_credentials",
        "client_id": 'gAJOLRiyFCjYVuCEIspShbBroNVLSgpw',
        "client_secret": 'ZDHiCX0h0NYIBm0B'
    }
 
    response = requests.post(url, headers=headers, data=data)
    if response.status_code == 200:
        # Extract the access token from the response JSON
        access_token = response.json()['access_token']
        print("Access Token:", access_token)
    else:
        # Print error message if the request was not successful
        print("Failed to obtain access token:", response.status_code, response.text)
    return access_token

# Get access token
access_token = get_access_token()
# Out:
# Access Token: AiejpxpLok3mdyYxO4AXDdrslizE

# %%
def get_flight_details(access_token, originLocationCode, destinationLocationCode, departureDate):
    url = "https://test.api.amadeus.com/v2/shopping/flight-offers"
    headers = {
        "Authorization": f'Bearer {access_token}',
        "Content-Type": "application/json"
    }
    params = {
        "originLocationCode": originLocationCode,
        "destinationLocationCode": destinationLocationCode,
        "departureDate": departureDate,
        "adults": 1,
        "max": 1
    }
 
    response = requests.get(url, headers=headers, params=params)
    if response.status_code == 200:
        return response.json()
    else:
        print("Failed to get flight details:", response.status_code, response.text)
        return None

# %%
print(airport_select.options[2])
print(city_select.options)
# Out:
# ATH
# ['Athens', 'Corfu', 'Crete', 'Zante', 'Mykonos']

# %%
# Call the function to get flight details
originLocationCode = 'ATH'
destinationLocationCode = 'JMK'
departureDate = '2024-06-13'
flight_offers_response = get_flight_details(access_token, originLocationCode, destinationLocationCode, departureDate)

# %%
if flight_offers_response:
    # Extract flight details and create DataFrame
    flight_data = []
    for flight in flight_offers_response['data']:
        itinerary = flight['itineraries'][0]
        segment = itinerary['segments'][0]
        departure_airport = segment['departure']['iataCode']
        arrival_airport = segment['arrival']['iataCode']
        departure_time = segment['departure']['at'][-8:-3]
        arrival_time = segment['arrival']['at'][-8:-3]
        # Convert string time to hours and minutes
        departure_hour, departure_minute = map(int, departure_time.split(':'))
        arrival_hour, arrival_minute = map(int, arrival_time.split(':'))
 
        # Calculate duration in minutes
        duration_minutes = (arrival_hour * 60 + arrival_minute) - (departure_hour * 60 + departure_minute)
 
        # Convert duration to hours and minutes
        duration_hours = duration_minutes // 60
        duration_minutes = duration_minutes % 60
 
        duration_str = f"{duration_hours:02d}:{duration_minutes:02d}"
        price = float(flight['price']['total'])
        currency = flight['price']['currency']
        price_with_currency = f"{price} {currency}"
 
        # Combine price with currency
        flight_data.append([departure_airport, arrival_airport, departure_time, arrival_time, duration_str, price_with_currency])
 
    # Creating DataFrame
    df = pd.DataFrame(flight_data, columns=['DepartureAirport', 'ArrivalAirport', 'DepartureTime', 'ArrivalTime', 'Duration(hours)', 'PriceWithCurrency'])
    display(df)
# Out:
#   DepartureAirport ArrivalAirport DepartureTime ArrivalTime Duration(hours)  \
# 0              ATH            JMK         06:15       07:00           00:45
#
#   PriceWithCurrency
# 0         52.99 EUR

# %%
flight_offers_response = get_flight_details(access_token, originLocationCode, destinationLocationCode, departureDate)
def process_flight_data(flight_offers_response):
    if flight_offers_response:
        # Extract flight details and create DataFrame
        flight_data = []
        for flight in flight_offers_response['data']:
            itinerary = flight['itineraries'][0]
            segment = itinerary['segments'][0]
            departure_airport = segment['departure']['iataCode']
            arrival_airport = segment['arrival']['iataCode']
            departure_time = segment['departure']['at'][-8:-3]
            arrival_time = segment['arrival']['at'][-8:-3]
 
            # Convert string time to hours and minutes
            departure_hour, departure_minute = map(int, departure_time.split(':'))
            arrival_hour, arrival_minute = map(int, arrival_time.split(':'))
 
            # Calculate duration in minutes
            duration_minutes = (arrival_hour * 60 + arrival_minute) - (departure_hour * 60 + departure_minute)
 
            # Convert duration to hours and minutes
            duration_hours = duration_minutes // 60
            duration_minutes = duration_minutes % 60
 
            duration_str = f"{duration_hours:02d}:{duration_minutes:02d}"
 
            price = float(flight['price']['total'])
            currency = flight['price']['currency']
            price_with_currency = f"{price} {currency}"
 
            # Combine price with currency
            flight_data.append([departure_airport, arrival_airport, departure_time, arrival_time, duration_str, price_with_currency])
 
        # Creating DataFrame
        df = pd.DataFrame(flight_data, columns=['DepartureAirport', 'ArrivalAirport', 'DepartureTime', 'ArrivalTime', 'Duration(hours)', 'PriceWithCurrency'])
        return df
    else:
        print("No flight offers data available.")
        return None

# %%
df = process_flight_data(flight_offers_response)
display(df)
# Out:
#   DepartureAirport ArrivalAirport DepartureTime ArrivalTime Duration(hours)  \
# 0              ATH            JMK         06:15       07:00           00:45
#
#   PriceWithCurrency
# 0         52.99 EUR

# %%
# Convert the DataFrame to a ColumnDataSource
source = ColumnDataSource(df)

# Define the columns for the DataTable
columns = [
    TableColumn(field='DepartureAirport', title='Departure Airport'),
    TableColumn(field='ArrivalAirport', title='Arrival Airport'),
    TableColumn(field='DepartureTime', title='Departure Time'),
    TableColumn(field='ArrivalTime', title='Arrival Time'),
    TableColumn(field='Duration(hours)', title='Duration (hours)'),
    TableColumn(field='PriceWithCurrency', title='Price')
]

# Create the DataTable
data_table = DataTable(source=source, columns=columns, width=800, height=280)

# Your existing code to create other widgets, e.g., city_select, airport_select, etc.

# Layout the widgets with city input, button, and result div
inputs = column(city_select, airport_select, date_range_picker, update_button)
header = column(logo_image, title_div)
results = column(recommended_dates_temp, recommended_dates_humidity, recommended_dates_wind_speed, result_div, data_table)
layout = column(header, inputs, results, sizing_mode='stretch_both', css_classes=['app-layout'])

# Display the plot
show(layout)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[65], line 23
#      21 header = column(logo_image, title_div)
#      22 results = column(recommended_dates_temp, recommended_dates_humidity, recommended_dates_wind_speed, result_div, data_table)
# ---> 23 layout = column(header, inputs, results, df, sizing_mode='stretch_both', css_classes=['app-layout'])
#      25 # Display the plot
#      26 show(layout)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\bokeh\layouts.py:153, in column(sizing_mode, *children, **kwargs)
#     127 """ Create a column of Bokeh Layout objects. Forces all objects to
#     128 have the same sizing_mode, which is required for complex layouts to work.
#     129
#    (...)
#     150     >>> column(children=[widgets, plot], sizing_mode='stretch_both')
#     151 """
#     152 _children = _parse_children_arg(*children, children=kwargs.pop("children", None))
# --> 153 _handle_child_sizing(_children, sizing_mode, widget="column")
#     154 return Column(children=_children, sizing_mode=sizing_mode, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\bokeh\layouts.py:640, in _handle_child_sizing(children, sizing_mode, widget)
#     638     continue
#     639 if not isinstance(item, LayoutDOM):
# --> 640     raise ValueError(f"Only LayoutDOM items can be inserted into a {widget}. Tried to insert: {item} of type {type(item)}")
#     641 if sizing_mode is not None and _has_auto_sizing(item):
#     642     item.sizing_mode = sizing_mode
#
# ValueError: Only LayoutDOM items can be inserted into a column. Tried to insert:   DepartureAirport ArrivalAirport DepartureTime ArrivalTime Duration(hours)  \
# 0              ATH            JMK         06:15       07:00           00:45
#
#   PriceWithCurrency
# 0         52.99 EUR   of type <class 'pandas.core.frame.DataFrame'>
